# %%
# !pip install --quiet pymongo

# %%
# !pip install -U pymongo
# Out:
# Requirement already up-to-date: pymongo in /opt/conda/lib/python3.6/site-packages

# %%
import pymongo
import pandas as pd
import pprint

# %%
client = pymongo.MongoClient('35.167.189.162', 27016)

# %% [markdown]
# ### Databases on MongoDB Server

# %%
client.database_names()
# Out:
# ['admin', 'local', 'project4_database', 'tweets']

# %% [markdown]
# ### Create a Reference to the `tweets` Database

# %%
tweets_db = client.tweets

# %%
tweets_db
# Out:
# Database(MongoClient(host=['35.167.189.162:27016'], document_class=dict, tz_aware=False, connect=True), 'tweets')

# %%
tweets_db.collection_names()
# Out:
# ['my_eg_collection']

# %% [markdown]
# ### Explore the `my_eg_collection` collection

# %%
#tweets_db.my_gulf_collection.drop()

# %%
for a in tweets_db.my_eg_collection.find():
    pprint.pprint(a)
# Out:
# {'_id': ObjectId('5a26dc22204c9e0253e6b196'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'kamal',
#  'cleaned_text': 'أزاي أقول لك كنا زمان ... والماضي كان فى الغيب بكره واللي '
#                  'أحنا فيه دلوقت كمان ... ح يفوت علينا ولا ندري'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b197'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'agabdelrehim',
#  'cleaned_text': 'هي آراء آه بس أزاي أجويرو منتهي يعني أمال لو مكنش الهداف '
#                  'التاريخي للسيتي و كل موسم اقل عدد من الاهداف…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b198'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'ElsndubadE',
#  'cleaned_text': 'أنت صيني أزاي تقارن شادي بالخطيب ألي هو الوحيد ألي خد الكورة '
#                  'الذهبية من مصر وبشهادت الزملكاوي قبل الأ…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b199'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'h_sawires',
#  'cleaned_text': 'أزاي الناس كانت بتغرد في الخمسينات قبل إختراع تويتر.'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b19a'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Hagerelmor',
#  'cleaned_text': 'التوينز اللي معاها كل الحلو والوحش والمصايب والاكل والفشل مش '
#                  'عارفه من غيرك كنت هعيش أزاي ربنا يخليكي ليا ومش تويته توصفك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b19b'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'YaraHossamElDin',
#  'cleaned_text': ': عن الناس إلي ربنا بعتهالك عشان يقولك شوف آخر صبرك طلع حلو '
#                  'أزاي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b19c'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'weaamaboelwafa1',
#  'cleaned_text': 'شوفت لما تجاهلت الناس وشك نور أزاي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b19d'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'hjjarr',
#  'cleaned_text': 'ده انا صاحيه من ساعه وزهقت هكمل أزاي بقيت اليوم من غير ما '
#                  'أنتحر'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b19e'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'amira_ashraf97',
#  'cleaned_text': 'أزاي اتعرفت علي افضل صديق/ة عندك/ي؟ — افضل صديقة عندي مع بعض '
#                  'من اولى ابتدائي مش فاكرة اتعرفنا ازاي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b19f'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'YasmeenShabana2',
#  'cleaned_text': 'اكيد مكنتيش هتقدري تعيشي ي بنتي ، انتي م غيري ولا اي حاجة '
#                  'أصلاً انا عارفهه ، وعارفه أن مش تويته توصفني ده اكي…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1a0'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'trbdKnADYIRSP7',
#  'cleaned_text': 'الله اكبر رووووووووعه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1a1'),
#  'cleaned_geo': 'فجأه لقتني منوفية',
#  'cleaned_name': 'i_asam',
#  'cleaned_text': 'أول مرة أسمع أغنية رق الحـبيب لأم كلثـوم كـامله حقيقي الست '
#                  'دي كـانت أزاي كدا !'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1a2'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'rehamaboelhamed',
#  'cleaned_text': ': أول مرة أسمع أغنية رق الحـبيب لأم كلثـوم كـامله حقيقي الست '
#                  'دي كـانت أزاي كدا !'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1a3'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'mahmoud_s58',
#  'cleaned_text': 'أزاي يعني واحد يكون مجرم ويطلع براة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1a4'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Mn3m_reda',
#  'cleaned_text': 'البعُد عنك خوف وأنا ع الرجوع ملهوف ، لكن أعود أزاي ومكاني '
#                  'كله ضيوف ...!'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1a5'),
#  'cleaned_geo': 'Saudi Arabia',
#  'cleaned_name': 'AbdullaFal',
#  'cleaned_text': ': أزاي كل مرة بنشوفكم فيها، بنحس كأنها أول مرة، بنحس بنفس '
#                  'اللهفة، نفس النظرة، نفس النفس الطويل اللي بناخده، و نفس حال…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1a6'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'titoozahran',
#  'cleaned_text': ': مش عارفة هصحي الساعه عشان احضر سكشن أزاي و الساعه دلوقتي '
#                  '!!'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1a7'),
#  'cleaned_geo': 'Cairo, Egypt ..',
#  'cleaned_name': 'omarmuhamed1',
#  'cleaned_text': ': الله اكبر رووووووووعه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1a8'),
#  'cleaned_geo': 'Ismalia, Egypt / سـَـهـَـر',
#  'cleaned_name': 'AbdelaZizo_',
#  'cleaned_text': ': أنت غيرت المقام كدا أزاي الشيخ ماشاء الله'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1a9'),
#  'cleaned_geo': 'Kuwait',
#  'cleaned_name': 'WASM2004',
#  'cleaned_text': 'مستنين أيه !! شوفوا اليمن وليبيا أزاي عملوا بالقذافي وصالح '
#                  'واعملوا زيهم'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1aa'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'mahmoud_hny',
#  'cleaned_text': 'لا يا عم ده حالق دقنه بس'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1ab'),
#  'cleaned_geo': 'كاتب صحفى',
#  'cleaned_name': 'KeroaiadKero',
#  'cleaned_text': ': لا يا عم ده حالق دقنه بس'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1ac'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'Ejal3mrii0',
#  'cleaned_text': ': اللي شُفته قبل مَا تشوفك عينيًّا عُمْر ضايع يحسبوه أزاي '
#                  'عليّا'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1ad'),
#  'cleaned_geo': 'Istanbul, Turkey',
#  'cleaned_name': 'etman_r2',
#  'cleaned_text': 'لا دا عشان حلقت بس'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1ae'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Dinaekrady',
#  'cleaned_text': ': لا دا عشان حلقت بس'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1af'),
#  'cleaned_geo': 'live in q8 .. bas masrya',
#  'cleaned_name': 'mariam_red',
#  'cleaned_text': 'أزاي اتعرفت علي افضل صديق/ة عندك/ي؟ — جامعه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1b0'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'EngHassanSaid1',
#  'cleaned_text': 'أزاي ابدأ في الشبكات | Network: via'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1b1'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'nadernashat',
#  'cleaned_text': 'جيل كامل من الأباء والأمهات ماعرفوش يربوا أولادهم أزاي يكون '
#                  'أنسان وان الشر از الظلم اللي انت اتعرضت له مش لازم ترده…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1b2'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'sarah_naggar',
#  'cleaned_text': 'أزاي عندك حب اﻷمتﻻك ده !!'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1b3'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'TaliaRamadan9',
#  'cleaned_text': ': اللي شوفته قبل ما تشوفك عنيّا.. عُمْر ضايع ، يحسبوه أزاي '
#                  'عليّا'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1b4'),
#  'cleaned_geo': 'New York, USA',
#  'cleaned_name': 'Dalia_PT',
#  'cleaned_text': 'و ده يتقال عليه كلب أزاي بس ️'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1b5'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'mohamed1mahran',
#  'cleaned_text': 'شوفت لما تجاهلت الناس وشك نور أزاي .'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1b6'),
#  'cleaned_geo': 'أتمشى بذا المجنونM',
#  'cleaned_name': 'm_5maria',
#  'cleaned_text': 'أزاي مختلف بصوت عادل أمام يعني أنا حوله'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1b7'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Hagerelmor',
#  'cleaned_text': ': اكيد مكنتيش هتقدري تعيشي ي بنتي ، انتي م غيري ولا اي حاجة '
#                  'أصلاً انا عارفهه ، وعارفه أن مش تويته توصفني ده اكي…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1b8'),
#  'cleaned_geo': 'برا عنك',
#  'cleaned_name': 'dodostart92',
#  'cleaned_text': 'أنتو أزاي مبتكلموش نفسكو أنتو مجانيبن..'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1b9'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'ahmed_ahmos35',
#  'cleaned_text': 'طب أزاي فيه حاجات بتموت وتيجي الصدفة تحيها'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1ba'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Nadiahamza77',
#  'cleaned_text': 'و أزاي مسمياهم صحاب !!'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1bb'),
#  'cleaned_geo': '╰_╯Alarish North Sina Egypt╰_╯',
#  'cleaned_name': 'modyfaress',
#  'cleaned_text': ': لما تبطل تستني حاجة من حد سواء ( إهتمام - كلمة حلوة - '
#                  'فُرصة ) وتعيش وتكبر دماغك عن مين قال إيه ، مين بيفكر فيك '
#                  'أزاي .. هتعي…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1bc'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'evilangel2264',
#  'cleaned_text': ': أنا مريض بمرض التفكير والتفاصييل.. لو أتكلمت مع حد كلمتين '
#                  'بس ، بحلل شخصيته ، وبحلل طريقه الكلام اللي قالهالي وادقق…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1bd'),
#  'cleaned_geo': 'Saudi Arabia',
#  'cleaned_name': 'TNm5y',
#  'cleaned_text': 'أزاي أوصفلك ياحبيبي أزاي قبل ما احبك كنت أزاي ياحبيبيييي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1be'),
#  'cleaned_geo': 'كوّكوّ تويتر',
#  'cleaned_name': 'm7md_mo5tar92',
#  'cleaned_text': 'ها ها ها هاااي أزاي أأجدع تقول الكلام ده ، طبعاً كنت بغش ...'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1bf'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'doniahesham1010',
#  'cleaned_text': 'سيبتك و قولت هما يومين و مسيري هرتاح و هنسى.. مش عارف أزاي و '
#                  'بعد سنين حضنك بيوحشني لسه!'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1c0'),
#  'cleaned_geo': 'كوّكوّ تويتر',
#  'cleaned_name': 'm7md_mo5tar92',
#  'cleaned_text': 'أنا فاكر فـ سنه من السنين لما كنت لسه فـ المدرسه حليت حوالي '
#                  'أمتحانات فـ ماده واحده فـ ساعت…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1c1'),
#  'cleaned_geo': 'ف البيت.',
#  'cleaned_name': 'Shahd_elmahroky',
#  'cleaned_text': ': شوفت لما تجاهلت الناس وشك نور أزاي .'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1c2'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'pinarpillar2002',
#  'cleaned_text': ': الشيخ محمد صديق المنشاوي بعث من جديد تقريبا أنا مش عارف هو '
#                  'أزاي قلده كدة بجد'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1c3'),
#  'cleaned_geo': 'Milano, Italy',
#  'cleaned_name': 'Rose_Hime_Sama',
#  'cleaned_text': ': ها ها ها هاااي أزاي أأجدع تقول الكلام ده ، طبعاً كنت بغش '
#                  '...'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1c4'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'mag_xen',
#  'cleaned_text': ': أنا فاكر فـ سنه من السنين لما كنت لسه فـ المدرسه حليت '
#                  'حوالي أمتحانات فـ ماده واحده فـ ساعت…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1c5'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'D38647416',
#  'cleaned_text': 'ازيك صباح الفل'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1c6'),
#  'cleaned_geo': 'Egypt↩Dubai',
#  'cleaned_name': 'luminooos',
#  'cleaned_text': 'اللهم آمين .. آمين .. آمين ازيك .. يارب تكون في احسن حال'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1c7'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'MohammedTalaat1',
#  'cleaned_text': ': اللهم آمين .. آمين .. آمين ازيك .. يارب تكون في احسن حال'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1c8'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'mohmedelhnawy24',
#  'cleaned_text': 'ازيك يا ادهم سليمان —'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1c9'),
#  'cleaned_geo': 'بولندا',
#  'cleaned_name': 's_ss3',
#  'cleaned_text': 'محمد علي ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1ca'),
#  'cleaned_geo': 'الاسكندرية',
#  'cleaned_name': 'adoom101',
#  'cleaned_text': 'لما البنت اللي بتحبها تكون واقفه مع ابوها وانت بقالك كتير '
#                  'مشوفتهاش والنبي ياحج متعرفش شارع ياواحشني رد عليا ازيك سل…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1cb'),
#  'cleaned_geo': 'Cairo',
#  'cleaned_name': 'Hazem__Azim',
#  'cleaned_text': 'ازيك يا محمد .. قلقتني عليك بشدة .. اختفائك .. ؟!'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1cc'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'mzeezm131',
#  'cleaned_text': ': ازيك يا محمد .. قلقتني عليك بشدة .. اختفائك .. ؟!'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1cd'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'ZZeko1997',
#  'cleaned_text': 'ازيك يا احلي وزه اعمل حسابك تيجيلي كل يوم الاوضه وتدينا حته '
#                  'ثقافيه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1ce'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'PwxRJC67w6wcykP',
#  'cleaned_text': 'ازيك يامى'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1cf'),
#  'cleaned_geo': 'الأسكندرية, مصر',
#  'cleaned_name': 'Mohamed1112216',
#  'cleaned_text': 'السلام عليكم ازيك يا كابتن ربنا يوفقك كنت عاوز اطلب منك حاجه '
#                  'بعداذنك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1d0'),
#  'cleaned_geo': 'Tanta Egypt',
#  'cleaned_name': 'Wael_Awad2',
#  'cleaned_text': 'ازيك يا كسمك. لما انت مش راجل وخول زيك زي خولات الجماعة تشتم '
#                  'وتجري؟ يابن ال…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1d1'),
#  'cleaned_geo': 'El Monofia, Egypt',
#  'cleaned_name': 'ganna701',
#  'cleaned_text': ': ازيك مش ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1d2'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'Kingof_sense',
#  'cleaned_text': 'ازيك ؟ عامله ايه ؟ وحشتنا وحشنا هزارك وكلامك غايبه بقالك '
#                  'كتير وسايبه الأيام تفوت كأن مفيش لكي أصحاب عاوزين يعرفوا…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1d3'),
#  'cleaned_geo': 'Cairo , Egypt',
#  'cleaned_name': 'mona_gendy',
#  'cleaned_text': 'ازيك يا ملوكة واراي ماما دلوقتي ؟!'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1d4'),
#  'cleaned_geo': 'Ciudad Real, Spain',
#  'cleaned_name': 'Omar_aalsaied',
#  'cleaned_text': 'هيوق هيوق هيوق'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1d5'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'bnootah_16',
#  'cleaned_text': 'صباحي مدام دودو ️ ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1d6'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'a4a49999',
#  'cleaned_text': 'حاجة ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1d7'),
#  'cleaned_geo': 'Mansoura',
#  'cleaned_name': 'drnaremanetman',
#  'cleaned_text': 'بوصى هو الشخصية اللى بكلمك عنها دى عصبية جدا وحتى ما فكروش '
#                  'يجو يتأسفو لا بالعكس قعدوا تلقيح وكلام ع ال…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1d8'),
#  'cleaned_geo': 'Saudi Arabia',
#  'cleaned_name': 'ahmdhedr311',
#  'cleaned_text': 'ازيك يافايز'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1d9'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'Aloula97',
#  'cleaned_text': "مرة شوية رز حبو يسلمو على مديرهم قالوله ازيك يا Rice ' هههه "
#                  'هههه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1da'),
#  'cleaned_geo': 'الدمام',
#  'cleaned_name': 'aleid_t',
#  'cleaned_text': 'هلاا بك نايف ازيك ي قميل'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1db'),
#  'cleaned_geo': 'Germany',
#  'cleaned_name': 'The_O_Power',
#  'cleaned_text': 'حتى ازيك مستخسرها مستكترها مابيقولهاش'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1dc'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Ibrahim1991116',
#  'cleaned_text': 'ازيك انتى بتعلمينى الصبر على البلاء افتكرى ده'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1dd'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'mariamshaker221',
#  'cleaned_text': ': حتى ازيك مستخسرها العرص مبيقولهاش'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1de'),
#  'cleaned_geo': 'اخر الدنيا',
#  'cleaned_name': 'AhmedZagloul5',
#  'cleaned_text': 'ازيك ي اخو'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1df'),
#  'cleaned_geo': 'في ارض الله الواسعه',
#  'cleaned_name': 'q5Z9vfeHMSpLCE4',
#  'cleaned_text': 'ازيك يابوبي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1e0'),
#  'cleaned_geo': 'mansoura . egypt',
#  'cleaned_name': 'shymaayussef',
#  'cleaned_text': 'بقلق اووي لما ألاقي بنت معرفهاش تقولي ازيك او هاي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1e1'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'zahraamohamd76',
#  'cleaned_text': 'ازيك كدا — الحمد لله تمام ️️'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1e2'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'MenNa_S_Radwan',
#  'cleaned_text': '*رايحه ازور عمتى* ازيك ياعمتو اخبارك وحشانى باسوورد الواى '
#                  'فاى ايه..'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1e3'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'HaythamAyman6',
#  'cleaned_text': 'هههههههههه ازيك يا دكتور علاء بسيطة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1e4'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'maamoo512',
#  'cleaned_text': ': علي السوشيال ميديا تلاقيها ب لسان طويل و اول ما تقابلها و '
#                  'تقولها ازيك خدودها بتتحول بقدره قادر ل كاتشب هاينز'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1e5'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'shemo5295',
#  'cleaned_text': 'طب م تقولي ازيك ف المايك كده يا صخره'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1e6'),
#  'cleaned_geo': 'فى اللانهائية وما بعدها',
#  'cleaned_name': 'VagueA_',
#  'cleaned_text': 'ازيك يا سماسم يا قمر. صباح الاناناس على اغلى الناس... — صباح '
#                  'النور'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1e7'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'ma7moud_74',
#  'cleaned_text': 'بسأل علي نفسي فبقولك ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1e8'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'kareemba_',
#  'cleaned_text': 'ازيك انت يا جميل... انتي كل صورة بتصغري عن اللي قبلها'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1e9'),
#  'cleaned_geo': 'El Monofia, Egypt shebin Elkom',
#  'cleaned_name': 'SarahKhattab13',
#  'cleaned_text': 'ازيك يا يارا عامل اه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1ea'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'sadeem3141',
#  'cleaned_text': 'ازيك يا مايكل يا اخونا في الوثن'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1eb'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'midomorad22',
#  'cleaned_text': 'ازيك يا ولد يا صلاح'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1ec'),
#  'cleaned_geo': 'Jordan Ksa .',
#  'cleaned_name': 'rara_albitar',
#  'cleaned_text': 'مره رز سلم على مديره قاله ازيك يا Rice 🤦\u200d️.'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1ed'),
#  'cleaned_geo': 'قرية الجية',
#  'cleaned_name': 'mhmdthammad97',
#  'cleaned_text': ': مره رز سلم على مديره قاله ازيك يا Rice 🤦\u200d️.'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1ee'),
#  'cleaned_geo': 'Gaza, Palestine',
#  'cleaned_name': 'AbooodXQ',
#  'cleaned_text': ": مرة شوية رز حبو يسلمو على مديرهم قالوله ازيك يا Rice ' "
#                  'هههه هههه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1ef'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'FATMA__1911',
#  'cleaned_text': 'عايزه حد يقولي ازيك عشان اتخانق معاه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1f0'),
#  'cleaned_geo': 'هناك في السلام الداخلي',
#  'cleaned_name': 'Ayaatttt',
#  'cleaned_text': 'صباح السكر . ازيك ياحسين كل سنه وانت طيب'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1f1'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'HADEER41252420',
#  'cleaned_text': 'مين انا لا ماليش دعوة انا لو اتكلمت هقولك السلام عليكم ازيك '
#                  'يا استاذ مصطفى عامل ايه وشكرا والسلام عليكم'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1f2'),
#  'cleaned_geo': 'zagazig',
#  'cleaned_name': 'EmanAbdelfatta6',
#  'cleaned_text': 'ازيك — الحمد للّه .'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1f3'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'LEV8ER',
#  'cleaned_text': 'ازيك يا بوصلاح نبي هاتريك السبت'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1f4'),
#  'cleaned_geo': 'السعودية',
#  'cleaned_name': 'falkwn90',
#  'cleaned_text': 'ازيك بقالنا خمس سنوات ملناش سيرة غير الاخوان والارهاب '
#                  'والكباب ومش عارفين نتخلص منهم برغم تفويض نارى اخدة الرئيس...'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1f5'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'Nody183',
#  'cleaned_text': 'ازيك |'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1f6'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'mohammed_attya',
#  'cleaned_text': 'ازيك يا باشمهندسة ^_^ حقيقي انتي من اكتر الناس اللي بحترمها '
#                  'هنا على تويتر'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1f7'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'esraa2tahaa',
#  'cleaned_text': 'قالتلي بس يابابا النهاردة اكتر م قالتلي ازيك ف حياتها'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1f8'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'ra2_281',
#  'cleaned_text': 'هاي ازيك ما تعرفيش اماكن في مصر بتعرض رسومات زي كدة؟ حاسة '
#                  'اني عايزة اقف قدام كل واحدة واديها وقته…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1f9'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'AishaHesham1',
#  'cleaned_text': 'ابن خالي داخل علي تيته بيقولها ازيك يا فايزه عامله ايه .. '
#                  'تيته بترد بتقولي حبيبي ابن الوسخه عامل ايه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1fa'),
#  'cleaned_geo': 'خـيالگـو المـريـض !',
#  'cleaned_name': 'AYO4_',
#  'cleaned_text': 'ازيك يا يويو — تمـام.'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1fb'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'shikoo_911',
#  'cleaned_text': 'ازيك يا ست شهد اخبارك ايه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1fc'),
#  'cleaned_geo': 'Tokyo.London',
#  'cleaned_name': 'tongue777',
#  'cleaned_text': 'القيعي خايف علي مستقبلك في النادي عامل ايه يا كابتن ... ازيك '
#                  'يا كابتن ......... اخبارك يا...'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1fd'),
#  'cleaned_geo': 'طنطا',
#  'cleaned_name': 'elfeky_manar',
#  'cleaned_text': 'مرة شوية رز حبو يسلمو على مديرهم قالوله ازيك يا Rice '
#                  'HaHaHaHaHaHa'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1fe'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'reda_fekri19',
#  'cleaned_text': 'وبناقص من كلمة ازيك لو بتقولوها عشان تبقوا عملتوا اللي '
#                  'عليكم...'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b1ff'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'anaarmy96',
#  'cleaned_text': 'هاي ازيك انا اسماء'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b200'),
#  'cleaned_geo': 'Cairo',
#  'cleaned_name': 'Ahmed84414729',
#  'cleaned_text': 'ازيك يأرهابى'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b201'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'anaarmy96',
#  'cleaned_text': 'هاي ازيك انا اسماء نتعرف ونتكلم ع الخاص ممكن لان انا متجوزه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b202'),
#  'cleaned_geo': 'Mansoura',
#  'cleaned_name': 'hmouda_eman',
#  'cleaned_text': 'ازيك يا صغنن اخبارك اي عاش من شافك — الحمد لله للاسف عايشه '
#                  'اهوه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b203'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'noorhan4555',
#  'cleaned_text': 'عليا اللقيطة ازيك حبيبتي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b204'),
#  'cleaned_geo': 'Tanta, Egypt',
#  'cleaned_name': 'Mo2men_Mo5tar',
#  'cleaned_text': 'ازيك يا صاحبي واحشني جدا و الله -طب متيجي نتقابل =لأ مش '
#                  'واحشني اوى كدا'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b205'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'RahmEhab',
#  'cleaned_text': 'ازيك — بخير ..'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b206'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'bvzaRRfmYz4dqG',
#  'cleaned_text': 'مبروك علينا كلينا حبيبي ياكابتن عصام مفيش ازيك بقا'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b207'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'sacsSld7wHYSIT6',
#  'cleaned_text': 'حببتي سما ازيك كل عام وانتي يؤلف خير'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b208'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'mariammarmar22',
#  'cleaned_text': ': فى لحظه بحس كلمه ازيك ليا ليها كل معانى العشق'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b209'),
#  'cleaned_geo': 'Cairo -Egypt',
#  'cleaned_name': 'tofky',
#  'cleaned_text': 'يا خبر ابياااض، ازيك يا مريم؟، و انت و الله ليكي وحشة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b20a'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'alharby1133',
#  'cleaned_text': 'أشده من قفاه واقوله ازيك الجراءة حلوة مفيش كلام'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b20b'),
#  'cleaned_geo': 'السعودية - جدة',
#  'cleaned_name': 'badr_1388',
#  'cleaned_text': ': …'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b20c'),
#  'cleaned_geo': 'mansoura',
#  'cleaned_name': 'Badr_esraa',
#  'cleaned_text': 'أنا عندى مشكله ف الكلام مع الناس شات والله..لو حد قالى ازيك '
#                  'بقول تمام..الحمد لله..كويسة.. لكن انى ارد اقول وانت ازي…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b20d'),
#  'cleaned_geo': 'Alexandria',
#  'cleaned_name': 'lina_rashwan',
#  'cleaned_text': 'ازيك يالينا صورك حلوه ع فكره ... — شكرا ي انون'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b20e'),
#  'cleaned_geo': 'underground',
#  'cleaned_name': 'Sherifbarakat35',
#  'cleaned_text': 'ازيك ي شريف — انا'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b20f'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'Thanaa_hassan',
#  'cleaned_text': 'كرامه ازيك يا بنتي يا رب تكوني بخير والله انتي اللي جميله'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b210'),
#  'cleaned_geo': 'El Daqahlia, Egypt',
#  'cleaned_name': 'mennaelshhawy',
#  'cleaned_text': 'اهلا ازيك — الحمدلله'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b211'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'skajdg',
#  'cleaned_text': 'هاي ازيك ابعتلي رسالة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b212'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'error_404_0',
#  'cleaned_text': 'الولية بقولها ازيك يا حاجه صباح الخير بتقولي صباح الخير ليه '
#                  'ياختي انتي لسه صاحيه!! *يا الله يا ولي الصابرين*'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b213'),
#  'cleaned_geo': 'Q8',
#  'cleaned_name': 'ashgAltha7ka',
#  'cleaned_text': 'هايات ازيك ي بنت'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b214'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'mahaaboelkheir',
#  'cleaned_text': 'لما بروح عند عمي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b215'),
#  'cleaned_geo': 'baghdad - iraq',
#  'cleaned_name': 'mustafa_safaa10',
#  'cleaned_text': 'ومرة تمن واكفين سوية وفات مديرهم كلولة ازيك يا rice'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b216'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'mozezo200',
#  'cleaned_text': 'ازيك — تماام الحمدلله'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b217'),
#  'cleaned_geo': 'الاسكندريه دائما وابدآ',
#  'cleaned_name': 'EnooD_ELsisi',
#  'cleaned_text': 'م الفل فؤش ازيك يا شقيق منور 🤣'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b218'),
#  'cleaned_geo': 'مصر ام الدنيا',
#  'cleaned_name': 'AhmedFoash10',
#  'cleaned_text': 'دة نورك يامعلمى'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b219'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'MenNa_S_Radwan',
#  'cleaned_text': ': لما بروح عند عمي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b21a'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'doktorato',
#  'cleaned_text': 'ازيك ياسحلوتشي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b21b'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'i_ad10',
#  'cleaned_text': 'هلا فيك ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b21c'),
#  'cleaned_geo': 'يلا مش مہم',
#  'cleaned_name': 'LionellaHANA',
#  'cleaned_text': '"لما احاول اتقل ع الكراش" -الو! --مش فاضية دلوقتي اكلمك '
#                  'بعدين! -طيب ازيك؟ --الحمدلله تمام.. ازيك انت، ايه اخبارك…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b21d'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'AlriyadhGannas',
#  'cleaned_text': 'ازيك يا مزمزيل'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b21e'),
#  'cleaned_geo': 'Cairo -Egypt',
#  'cleaned_name': 'cocogeorge83',
#  'cleaned_text': 'مساء الفل برة ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b21f'),
#  'cleaned_geo': 'Cairo -Egypt',
#  'cleaned_name': 'cocogeorge83',
#  'cleaned_text': 'مساء الورد شيماء ازيك عامله ايه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b220'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'ashikti',
#  'cleaned_text': 'مساء النور علي البنور ازيك ي nada'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b221'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Ahmed76772010',
#  'cleaned_text': '- انا في البعد مش زيك .. طب ازيك !'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b222'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'SwelamHassan',
#  'cleaned_text': 'ازيك يا مريم ؟؟ أخبارك ؟'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b223'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'wLsRdyB6q14ke8x',
#  'cleaned_text': 'ازيك يا اتش كيفك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b224'),
#  'cleaned_geo': 'يوم ف السويس و في المقطم',
#  'cleaned_name': 'TAREKmcTETO',
#  'cleaned_text': 'ركبت الأسانسير كانت فـي بنت واقفه جوا واقفه ورايا راحت قالت '
#                  'ازيك قولت حمدلله و ببص ورايا علشان اشوف مـين لقيتها ب…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b225'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'merooo1242',
#  'cleaned_text': 'غاده ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b226'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'AhmedCR10',
#  'cleaned_text': 'ازيك يا عم صاحب التوتير'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b227'),
#  'cleaned_geo': 'S A U D I A R A B I A',
#  'cleaned_name': 'M_A_Alshehri9',
#  'cleaned_text': 'ازيك يابو صلاح'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b228'),
#  'cleaned_geo': 'Saudi Arabia',
#  'cleaned_name': 'Mola7dat',
#  'cleaned_text': ': ازيك يابو صلاح'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b229'),
#  'cleaned_geo': 'صلالة / أرض الأصالة واللبان',
#  'cleaned_name': 'malooksadi1000',
#  'cleaned_text': 'ازيك ياورد'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b22a'),
#  'cleaned_geo': '🇸🇦️',
#  'cleaned_name': 'fJuve3',
#  'cleaned_text': 'ازيك يابو مكة ماتعيطش مش حنضرب جامد -٠ عليكم كفاية'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b22b'),
#  'cleaned_geo': 'Jeddah / KSA',
#  'cleaned_name': 'Thaimzzz',
#  'cleaned_text': 'ازيك يا جميل... بالحضن يا حبيبي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b22c'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'ahmdofmadrid',
#  'cleaned_text': 'ازيك يا صلاح واحشتني'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b22d'),
#  'cleaned_geo': 'mahmoudbenkamal.Sarahah.com',
#  'cleaned_name': 'mahmoudbenkamal',
#  'cleaned_text': 'الناس بتتريق على الاشخاص اللى بتبقى بتسال عليها لوجه الله '
#                  'المحادثات اللى هى بتبقى ازيك ؟ الحمد لله وانت ؟ انا الح…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b22e'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'shadysaeid75',
#  'cleaned_text': 'ازيك ياللي مابتساليش'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b22f'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'shadysaeid75',
#  'cleaned_text': 'ساره ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b230'),
#  'cleaned_geo': 'القلعة',
#  'cleaned_name': 'CaptinNamq',
#  'cleaned_text': 'ازيك يا ابو صلاح ، الجمهور السعودي بيحبك وبنشجع عشانك يا '
#                  'حبيب السعوديين .. ممكن تخف علينا في كاس ال…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b231'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'H0znbz1H7TryEFA',
#  'cleaned_text': 'تمام ازيك انتي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b232'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'ahmed_elghoull',
#  'cleaned_text': '- ازيك فاكرني ؟ - اه طبعآ وهيا الأشكال الوسخة تتنسي !'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b233'),
#  'cleaned_geo': 'بنى سويف, مصر',
#  'cleaned_name': 'fathy_waleid',
#  'cleaned_text': 'ازيك ي كابتن ابراهيم من الاعلامين ال بعزهم والله.. من الممكن '
#                  'ان تؤثر لوجود الخلافات ممايؤدي لعدم الاست…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b234'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Alkeshky1',
#  'cleaned_text': ': ازيك يا ميكى وازى ميتين امك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b235'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'MasryaAna15',
#  'cleaned_text': 'ازيك يا ابت ياعصفوره كل سنه وانتى طيبه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b236'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'elzamalkawea',
#  'cleaned_text': ': ازيك يا ابت ياعصفوره كل سنه وانتى طيبه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b237'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'HamadaElsaeedO2',
#  'cleaned_text': 'ازيك ياكابتن محمد المنوفية بتحيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b238'),
#  'cleaned_geo': 'في بيتنا',
#  'cleaned_name': 'Eman_Batoot35',
#  'cleaned_text': ': أشده من قفاه واقوله ازيك الجراءة حلوة مفيش كلام'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b239'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'medhathenawy',
#  'cleaned_text': 'أخرقصيده لى بالفصحى يا أيتها الغائبه عني... ازيك وازي امك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b23a'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'nGjOVhxZdbqgeNU',
#  'cleaned_text': 'ازيك ياعمرو باشا انا ضياء البنا محاسب مقيم في السعوديه ومن '
#                  'مركز قويسنا المنوفيه العمر سنه الحال اليج…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b23b'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'ZozoDeAna1',
#  'cleaned_text': ': ازيك يا شيف ممكن طريقة عمل السجاير في البيت'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b23c'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'JanValgan171',
#  'cleaned_text': 'هو الاخ نيكولاس قالب على عبد الله السعيد كده ليه ؟ لا والاخت '
#                  'صابرين رايحه تقوله ازيك ياعبد الله قالها لا أنا متحت ش…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b23d'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'AsYaa_361',
#  'cleaned_text': 'ازيك يامحمود عامل ايه اوعي تكون انت كمان مختفي ليه كلنا '
#                  'هانختفي ويفضل السيسي بس'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b23e'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'kaptain1001',
#  'cleaned_text': ': ازيك يامحمود عامل ايه اوعي تكون انت كمان مختفي ليه كلنا '
#                  'هانختفي ويفضل السيسي بس'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b23f'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'merooo1242',
#  'cleaned_text': 'ازيك يا ايموووو انا مي الى فى تيم عصابه المافيه كلمينى دى ام '
#                  'ممكن'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b240'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'saranaeem649',
#  'cleaned_text': ': بكلم اختي من شويه چنا مسكت التيلفون وعايزه تكلمني قولتلها '
#                  'امشي من وشي مش عايزه دوشه وهاتي امك ..العيال مبتكرهنيش من…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b241'),
#  'cleaned_geo': 'Saudi Arabia',
#  'cleaned_name': 'shlhob2_shlhob',
#  'cleaned_text': ': ازيك يا صلاح واحشتني'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b242'),
#  'cleaned_geo': 'Tanta',
#  'cleaned_name': 'ra2eeboo',
#  'cleaned_text': 'اسخم واوسخ ربنا معاكم يابنتى من كتر المذاكرة يعينى لو حد '
#                  'قالك ازيك ممكن تشرحيله العناصر الطبيعية'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b243'),
#  'cleaned_geo': 'فوق السوبر ماركت',
#  'cleaned_name': 'SaraMHamada50',
#  'cleaned_text': ': - ازيك فاكرني ؟ - اه طبعآ وهيا الأشكال الوسخة تتنسي !'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b244'),
#  'cleaned_geo': 'السويس, مصر',
#  'cleaned_name': 'Ahmed_Byeoyd',
#  'cleaned_text': 'ازيك ياموهيتي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b245'),
#  'cleaned_geo': '',
#  'cleaned_name': 'mahmod99999999',
#  'cleaned_text': 'ازيك يا صاحبي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b246'),
#  'cleaned_geo': 'في الفناء حيث اللامكان سواي!',
#  'cleaned_name': 'iam_jokes',
#  'cleaned_text': 'وعليكو الصلام ازيك ياابو صلتان'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b247'),
#  'cleaned_geo': 'السويس بلد الغريب',
#  'cleaned_name': 'DoaaNazmy3',
#  'cleaned_text': 'ازيك ؟؟'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b248'),
#  'cleaned_geo': '🇪🇬🇪🇬',
#  'cleaned_name': 'samsoma_442',
#  'cleaned_text': 'ازيك صبرينو عامل ايه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b249'),
#  'cleaned_geo': 'جنوب سيناء, مصر',
#  'cleaned_name': 'sinawia',
#  'cleaned_text': ': ازيك ياموهيتي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b24a'),
#  'cleaned_geo': 'Hashemite Kingdom of Jordan',
#  'cleaned_name': 'hindaqeel95',
#  'cleaned_text': 'مره شويه رز حبو يسلمو على مديرهم قالولو ازيك يا rice'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b24b'),
#  'cleaned_geo': 'Como, Lombardia-Italy',
#  'cleaned_name': 'EAboulin',
#  'cleaned_text': 'طيب ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b24c'),
#  'cleaned_geo': 'cairo',
#  'cleaned_name': 'Esoo_shaheen',
#  'cleaned_text': 'وانتي ازيك و ازيك كده'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b24d'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'qtr55141',
#  'cleaned_text': 'هههه زيي. !! واضح انك جاي علئ خشبه من مصر المهم انه مجنس. '
#                  'يعني تفرق اذا يتكلم عربي و…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b24e'),
#  'cleaned_geo': 'North Sinai, Egypt',
#  'cleaned_name': 'MarwaMohamed_1',
#  'cleaned_text': ': _ هاي , ازيك = مين ؟؟ _ انا خوازيق قولت اكلمك بدري عشان '
#                  'نلحق السنة من اولها'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b24f'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'zeenahamdy',
#  'cleaned_text': 'ازيك يا احلى'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b250'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'ramadan617',
#  'cleaned_text': 'ازيك يا الأعذار عامله ايه اميرة بتسلم عليكى'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b251'),
#  'cleaned_geo': 'non of your bussines',
#  'cleaned_name': 'nourai208',
#  'cleaned_text': ': ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b252'),
#  'cleaned_geo': 'Mansoura',
#  'cleaned_name': 'Galiliovic',
#  'cleaned_text': 'محدش يقولها ازيك يا جماعه عشان بتعيط'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b253'),
#  'cleaned_geo': 'portsaid -cairo- london',
#  'cleaned_name': 'mkhaled1983',
#  'cleaned_text': 'ازيك بروفيلك جرئ و عاجبني لاني انا كمان فري اوي و بحب البنت '
#                  'الجريئه وحابب اتعرف عليكي .. مبدئيا انا محمد دكتور'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b254'),
#  'cleaned_geo': 'irbid, Jordan khobar, KSA',
#  'cleaned_name': 'ruba2622',
#  'cleaned_text': 'حلوة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b255'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'nourhan80673712',
#  'cleaned_text': 'ازيك يا حلو — احسن منك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b256'),
#  'cleaned_geo': 'gaza',
#  'cleaned_name': 'alhassan8589',
#  'cleaned_text': 'ده لو بقى'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b257'),
#  'cleaned_geo': 'El Gharbia, Egypt',
#  'cleaned_name': 'EbraHim_SamYa',
#  'cleaned_text': 'اه والله'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b258'),
#  'cleaned_geo': 'Dubai, نابلس',
#  'cleaned_name': 'DanaaIsHere',
#  'cleaned_text': ': مرة شوية رز حبو يسلمو عمديرهم قالوله ازيك يا Rice ههه هه ه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b259'),
#  'cleaned_geo': 'المنوفية, مصر',
#  'cleaned_name': 'BeshoHema',
#  'cleaned_text': 'ايه رأيك في الشخص اللي بيبعت رسايل لناس ميعرفهاش على السوشال '
#                  'ميديا ؟! سواء ازيك او اخبارك "بين قوسين يعن… — مش عارف'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b25a'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'MeroToman',
#  'cleaned_text': '*همسك في خناقه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b25b'),
#  'cleaned_geo': 'non of your bussines',
#  'cleaned_name': 'nourai208',
#  'cleaned_text': ': ده لو بقى'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b25c'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'wafaaasharf434',
#  'cleaned_text': 'علاقة الناس بيا مصالح بس ريكورد ورق اي حاجه بس ان حد فيهم '
#                  'مره اخطر ع باله يسال عليا ويقولي حتى مالك لما ابقى مضايقه…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b25d'),
#  'cleaned_geo': 'الاسكندرية',
#  'cleaned_name': 'Mohamed45107862',
#  'cleaned_text': ': *همسك في خناقه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b25e'),
#  'cleaned_geo': 'الاسكندرية',
#  'cleaned_name': 'Mohamed45107862',
#  'cleaned_text': ': اه والله'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b25f'),
#  'cleaned_geo': 'مايلزمكش',
#  'cleaned_name': 'ashry_00',
#  'cleaned_text': 'عندي فراغ عاطفي لدرجه ان لو حد قالي ازيك راح قوله '
#                  'بحبكتشتري_ايه_ب50_جنيه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b260'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'MOU_st6',
#  'cleaned_text': 'اهلا نوف ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b261'),
#  'cleaned_geo': 'ولد في /أغسطس',
#  'cleaned_name': 'aminaminamin013',
#  'cleaned_text': 'مساء النور والسرور ازيك ياست هانم'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b262'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'chebih',
#  'cleaned_text': 'عائلات معتقلي اكديم ازيك يضربون عن الطعام تضامنا مع أبنائهم '
#                  'بسجون الاحتلال المغربية'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b263'),
#  'cleaned_geo': 'Irbid, Hashemite Kingdom of Jordan',
#  'cleaned_name': 'anwar_aqee',
#  'cleaned_text': 'شوو نهفة هلبنت'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b264'),
#  'cleaned_geo': 'في المعلش',
#  'cleaned_name': 'BosyMoh1',
#  'cleaned_text': 'دودو ي حبيبتي ازيك ️'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b265'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'gmJEO4Sc4zRbh9I',
#  'cleaned_text': 'ازيك كابتن محمد اسمي ابراهيم مولود في قريه صغيره حلمي انا '
#                  'العب في الدوري بس للأسف كل لما اروح ن…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b266'),
#  'cleaned_geo': 'اللابوريا',
#  'cleaned_name': 'myada98',
#  'cleaned_text': 'ازيك ؟؟ — تمام كويسة الحمد لله What about you ?'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b267'),
#  'cleaned_geo': 'my small world',
#  'cleaned_name': 'doaa_kamiss',
#  'cleaned_text': ': دودو ي حبيبتي ازيك ️'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b268'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'rezwoo25',
#  'cleaned_text': 'ازيك يا قمر'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b269'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'amGad20455323',
#  'cleaned_text': 'هي مجرد فتره تتعرفو علي بعد كدا اخريهم ازيك الحمدالله كويس '
#                  'وانت'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b26a'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'bent_alfayroooz',
#  'cleaned_text': 'كويسه ازيك انتي ههههه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b26b'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'bent_alfayroooz',
#  'cleaned_text': ': مساء النور والسرور ازيك ياست هانم'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b26c'),
#  'cleaned_geo': 'ولد في /أغسطس',
#  'cleaned_name': 'aminaminamin013',
#  'cleaned_text': ': كويسه ازيك انتي ههههه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b26d'),
#  'cleaned_geo': 'alexandria',
#  'cleaned_name': 'esraaaaa2_diaab',
#  'cleaned_text': 'ازيك يا سوتو ولا بتسألي ولا اي حاجه... — دنيا بقا'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b26e'),
#  'cleaned_geo': 'جيزان،الممكة العربية السعودية',
#  'cleaned_name': 'Alkhormi6',
#  'cleaned_text': 'مساالخير ازيك يادلوعه برسلك الى تبين ولاابي منك شئ لوجه الله'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b26f'),
#  'cleaned_geo': 'بلد ال مليون زقزوق',
#  'cleaned_name': 'ph_Elgebally',
#  'cleaned_text': 'استفسار بس ياريت رد منطقي فيه أشخاص ممكن نكون نعرفهم وعلاقة '
#                  'عادية بمعني ازيك وعامل ايه وخلاص ونادراً مابتتكلموا وكد…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b270'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'SaM_Sala7',
#  'cleaned_text': 'ازيك ياسارة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b271'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'BetoulAdel',
#  'cleaned_text': 'ازيك — تمام الحمد الله And you?!'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b272'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'awad53',
#  'cleaned_text': 'اهلين شمس ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b273'),
#  'cleaned_geo': 'mansoura',
#  'cleaned_name': 'Mai_Megahed25',
#  'cleaned_text': 'انا الفترة ديه مخنوقة لدرجة لو حد قالي ازيك حعيط .'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b274'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'GhadaElbaroudi',
#  'cleaned_text': 'ازيك يا دودو؟ — الحمد لله'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b275'),
#  'cleaned_geo': 'None',
#  'cleaned_name': '_Mo_Hga',
#  'cleaned_text': 'والقطه اللي اول ماحد بيقولها ازيك تاخدله سكرين شوت وتقولك '
#                  'بيتحرشو بيا'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b276'),
#  'cleaned_geo': 'مصر ام الدنيا',
#  'cleaned_name': 'MwwDEx0QxzIDGbn',
#  'cleaned_text': 'ازيك يابت'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b277'),
#  'cleaned_geo': 'اخر كوكب فِ الدنيا.',
#  'cleaned_name': '_sshhiimmoo_',
#  'cleaned_text': 'انا فل الحمدلله ازيك انت موجوده اهو'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b278'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'fawaz2050',
#  'cleaned_text': 'ازيك يا طويطرية'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b279'),
#  'cleaned_geo': 'El Monofia, Egypt',
#  'cleaned_name': 'dodo_tarik38',
#  'cleaned_text': '- ازيك = حلو .. لما بتسألي عني'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b27a'),
#  'cleaned_geo': 'Alexandria',
#  'cleaned_name': 'A__virus__',
#  'cleaned_text': 'زالفل انتي ازيك ياست و ازي عيالك فينك مش باينه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b27b'),
#  'cleaned_geo': 'Libya',
#  'cleaned_name': 'sfyansoheb',
#  'cleaned_text': 'حتى ازيك مستخسرها'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b27c'),
#  'cleaned_geo': 'حارة اليهود',
#  'cleaned_name': 'official_walaa',
#  'cleaned_text': ': يا ايتها السعاده الغائبه عني ازيك كدا وازي امك....! ؟'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b27d'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'sh3ov',
#  'cleaned_text': 'حتى ازيك مستكثرها مابيئولهاش'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b27e'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'hamdigharaibh',
#  'cleaned_text': ': مره شويه رز حبو يسلمو على مديرهم قالولو ازيك يا rice'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b27f'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'SissyAmjad',
#  'cleaned_text': 'بجد دا الكلام الصحيح ازيك ست سوزي عامله ايه وازاي صحتك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b280'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'ikareem_84',
#  'cleaned_text': ': كيفك قال عم بيقولوا صار عندك ولاد ؟ - لا بنات طب ربنا يخلي '
#                  '- الله يخليكي انتي ازيك وازي أمك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b281'),
#  'cleaned_geo': 'Hashemite Kingdom of Jordan',
#  'cleaned_name': 'hindaqeel95',
#  'cleaned_text': ': شوو نهفة هلبنت'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b282'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Mohamed58531167',
#  'cleaned_text': 'علي فكره دي ميزه من مميزات الشعب الالماني اني لو قولت له '
#                  'ازيك هيقولك الله يسلمك وشكرا'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b283'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'Marawan90381063',
#  'cleaned_text': ': ازيك يختي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b284'),
#  'cleaned_geo': 'Q8',
#  'cleaned_name': 'ashgAltha7ka',
#  'cleaned_text': 'ازيك ي مها'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b285'),
#  'cleaned_geo': 'Q8',
#  'cleaned_name': 'ashgAltha7ka',
#  'cleaned_text': 'ازيك ي بنت'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b286'),
#  'cleaned_geo': 'Saudi Arabia',
#  'cleaned_name': 'gghhdhj58752',
#  'cleaned_text': 'اهلا ي ولد'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b287'),
#  'cleaned_geo': 'تميم المجد " Dec 🇶🇦 "',
#  'cleaned_name': 'Al_8na',
#  'cleaned_text': 'ازيك ي خويا وازي عيالك وازي ذودك وازي كلن بزيوه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b288'),
#  'cleaned_geo': 'None',
#  'cleaned_name': '_al8',
#  'cleaned_text': 'ماتركب ذودك مع ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b289'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'Sweetmayouya',
#  'cleaned_text': 'ازيك و أزي المدام و الولاد'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b28a'),
#  'cleaned_geo': 'UAE 🇦🇪 - Egypt 🇪🇬',
#  'cleaned_name': 'nmnm8490',
#  'cleaned_text': 'الحمدلله ازيك ياعمرو'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b28b'),
#  'cleaned_geo': 'الركن البعيد الهادى',
#  'cleaned_name': 'amrmagyvar',
#  'cleaned_text': 'كويسين ودي مايوياا بنتي سلمي علي طنط'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b28c'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'Sweetmayouya',
#  'cleaned_text': ': كويسين ودي مايوياا بنتي سلمي علي طنط'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b28d'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'Nnjoood2',
#  'cleaned_text': 'اكييد واللي ضاحك مين ازيك ياقلبي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b28e'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Shahd6167',
#  'cleaned_text': 'جدا اقسم بالله'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b28f'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'me3allem',
#  'cleaned_text': 'ماشي الحال يا صاحبي عامل ايه انت'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b290'),
#  'cleaned_geo': 'Benghazi_LY ️',
#  'cleaned_name': 'esra_anwer',
#  'cleaned_text': 'زفته ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b291'),
#  'cleaned_geo': 'Interlaken, Schweiz',
#  'cleaned_name': 'l_3zi',
#  'cleaned_text': 'منيح ازيك ؟'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b292'),
#  'cleaned_geo': 'الامارات',
#  'cleaned_name': 'Bo_shi5a',
#  'cleaned_text': '…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b293'),
#  'cleaned_geo': 'Mansoura - Egypt',
#  'cleaned_name': 'Salma_Zakaria93',
#  'cleaned_text': 'Patient كنت بشتغلها كل شوية تبعتلي على ال whatsApp تقولي '
#                  'ازيك يا سلومتي وحشتيني يا قلبي و يمكن دي احلى حاجة السنة دي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b294'),
#  'cleaned_geo': 'Lur, Egypt',
#  'cleaned_name': 'hussein_elramly',
#  'cleaned_text': ': Patient كنت بشتغلها كل شوية تبعتلي على ال whatsApp تقولي '
#                  'ازيك يا سلومتي وحشتيني يا قلبي و يمكن دي احلى حاجة السنة دي '
#                  '…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b295'),
#  'cleaned_geo': 'القصيم',
#  'cleaned_name': 'lmnfc1',
#  'cleaned_text': 'هلابك ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b296'),
#  'cleaned_geo': 'assuit,egypt',
#  'cleaned_name': 'ewes',
#  'cleaned_text': 'ازيك يا عويس وحشت محبي مش باين ليه؟... — انت ترحم دين امى ده '
#                  'مبدأيا'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b297'),
#  'cleaned_geo': 'International',
#  'cleaned_name': 'mo7ammed_ali7',
#  'cleaned_text': 'أنا الأسبوع دا So depressed لدرجة لو حد قالي ازيك هاكله '
#                  'ألمين'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b298'),
#  'cleaned_geo': 'الأقصر, مصر',
#  'cleaned_name': 'MohamedZ28894',
#  'cleaned_text': 'ازيك يا عفيفي..بعيدا عن سؤال الحلقة...عايز اقول حاجة كروية '
#                  'بحتة بعيدا عن الانتماء بصراحة أريد لميسي أن…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b299'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'beshogeorge1',
#  'cleaned_text': 'ممكن نلغي سؤال ازيك عشان مالوش لازمة خالص ؟'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b29a'),
#  'cleaned_geo': 'Egypt (Menofia) - KSA (Tabouk)',
#  'cleaned_name': 'MahmmoudElsayad',
#  'cleaned_text': ': الساعه - ازيك يا محمود لامحمود ايه .. قوليلى يا محاميحو'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b29b'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'PassantAyman_',
#  'cleaned_text': 'يا واحشني رد عليا ازيك سلامات — و عليكم السلام'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b29c'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'KhattabSally',
#  'cleaned_text': 'مساء الخيرات ي احمد ازيك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b29d'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'RwanZakariia',
#  'cleaned_text': 'مرة شوية رز حبو يسلمو على مديرهم قالوله ازيك يا Rice ههه هه '
#                  'ه️️'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b29e'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'my__querencia',
#  'cleaned_text': 'لما تبقى بتكلمى واحد وفجأة تلاقيه ادى الموبايل لباباه يكلمك '
# ...
#  'cleaned_name': 'Medhaat74',
#  'cleaned_text': 'ورقة وقلم و بحر و الاغانى بتاعتى و ازازة ابسليوت و كوباية '
#                  'تلج و كيوى و برقوق متقطعين ،،، ويلا ن Plan للمستقبل المريب '
#                  'ده'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b350'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'DAlmrasy',
#  'cleaned_text': 'والله ياجماعة احنا مستغنين عن مواعظكم وفاهمين كويس ان كل '
#                  'حاجه بتعدي بس انتم اللي بهايم ومش قادرين تفهموا انها وهيا…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b351'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'Ahmedshakban',
#  'cleaned_text': 'امي عاملالي كوباية قهوة وحاطة عليها شطة حمرا'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b352'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'samar618',
#  'cleaned_text': 'لما بتكسر كوباية بنروح بسرعة نلمها ونرميها في الزبالة ينفع '
#                  'عشان احنا بنحب الكوباية دى وعزيزه علينا نلزقها وخلاص...'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b353'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Midotarek_7',
#  'cleaned_text': 'قعده فوق السطوح ساعة العصاري مع كوباية شاي ع الرايق من ايدي '
#                  'الجميلة…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b354'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Midotarek_7',
#  'cleaned_text': 'قعده فوق السطوح ساعة العصاري مع كوباية شاي ع الرايق من ايدي '
#                  'الجميلة وفيروز العظيمة أحلي قعدة دي ولا ايه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b355'),
#  'cleaned_geo': 'القاهره',
#  'cleaned_name': 'daadpub',
#  'cleaned_text': ': كتاب و كوباية قهوه و مزيكا هاديه ..'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b356'),
#  'cleaned_geo': 'جمهورية كيميت ( Egypt )',
#  'cleaned_name': 'SandyMaherG',
#  'cleaned_text': 'أنا نفسي في كوباية نسكافية عمايل أيديا'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b357'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'tuqyoh',
#  'cleaned_text': 'رابطة-الناس اللي بتحط كوباية الشاي/نسكافيه على رُكبتها- و '
#                  'الناس اللي بتخاف لأ'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b358'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'elhamamsy1234',
#  'cleaned_text': 'حتى ده كمان طيب كوباية ميه عشان اتكل بقى'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b359'),
#  'cleaned_geo': 'egypt',
#  'cleaned_name': 'noorelhoda5050',
#  'cleaned_text': 'لا ده ننزل نشرب كوباية الفراوله بتاعت كل يوم بقى'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b35a'),
#  'cleaned_geo': 'elobour',
#  'cleaned_name': 'swelam_ayman',
#  'cleaned_text': ': ما يفسده العالم تصلحه كوباية شاى بالنعناع'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b35b'),
#  'cleaned_geo': 'Zagazig',
#  'cleaned_name': 'AhmedAdel12896',
#  'cleaned_text': 'رابع كوباية شاي اشربها النهاردة مش عارف في اية'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b35c'),
#  'cleaned_geo': 'بلاد الله الواسعة',
#  'cleaned_name': 'safi_2000',
#  'cleaned_text': 'والله شاطر في ناس ولا بتعرف تعمل كوباية شاي حتى بس انت جدع '
#                  'وان شاء الله تتهنى و تتجوز قريب و ربن…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b35d'),
#  'cleaned_geo': 'Mansoura , توريل Riadh ,saudi',
#  'cleaned_name': 'bakrelnagdi',
#  'cleaned_text': 'انت بقي مين اصلا عشان يتقدم لك كوباية قهوة عليها القيمة اخرك '
#                  'مياة سخنة عليها تفافة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b35e'),
#  'cleaned_geo': 'zagazig',
#  'cleaned_name': 'Amgad_Ashraf1',
#  'cleaned_text': 'بعمل كوباية شاى ف ساعه ونص لا إله الا الله!'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b35f'),
#  'cleaned_geo': 'Al Minufiyah, Egypt',
#  'cleaned_name': 'dinaramadan60',
#  'cleaned_text': 'هى المشكلة مش فى الساعة والنص والله المشكلة انها بعد ده كله '
#                  'بتطلع مش مظبوطة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b360'),
#  'cleaned_geo': 'England, United Kingdom',
#  'cleaned_name': 'yahya_salah23',
#  'cleaned_text': 'حياتي المهنية كلها بتتأخر لما كوباية الشاي بتتأخر'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b361'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'AhmedMea2',
#  'cleaned_text': 'طيب ريحي شويه.....اشربي كوباية نسكافيه واسمعي حاجه لفيروز'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b362'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'amirashahin20',
#  'cleaned_text': ': انا حاسة اني عاوزة حد يستأصل الجزء المسئول عن القرارات '
#                  'فحياتي ويحطلي مكانه كوباية شاي افيد والله وهتعالج الصداع'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b363'),
#  'cleaned_geo': 'البؤساء',
#  'cleaned_name': 'mai_homos',
#  'cleaned_text': ': تحس كوباية الشاي رامية صنارة وبتصطاد'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b364'),
#  'cleaned_geo': 'zagazig',
#  'cleaned_name': 'Amgad_Ashraf1',
#  'cleaned_text': ': هى المشكلة مش فى الساعة والنص والله المشكلة انها بعد ده '
#                  'كله بتطلع مش مظبوطة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b365'),
#  'cleaned_geo': 'Egypt_texas',
#  'cleaned_name': 'shabeb2010',
#  'cleaned_text': 'لا احنا خلينا ف الاخيره بس كده'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b366'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'FinallyAdham',
#  'cleaned_text': ': انا مكنتش مهتم خالص بصراحة غير بدرجة برودة كوباية السوبيا '
#                  'اللي بيصبها وامتزاج مكوناتها.. المهم، بعد ما خلصت قولتل…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b367'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'LeMasry',
#  'cleaned_text': 'استهدي بالله كدة و اعمليلك كوباية نسكافية و اقعدي اتفرجي ع '
#                  'المسلسل'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b368'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'LeMasry',
#  'cleaned_text': 'الناس ف اسوان رايقة و بتعمل كل حاجة علي مهلها، هنا في '
#                  'القاهرة بنجري طول الوقت، لدرجة ان كوباية الشاي بنعملها و '
#                  'احنا مستعجلين.'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b369'),
#  'cleaned_geo': 'البحر الأحمر, مصر',
#  'cleaned_name': 'MostafaAbeed74',
#  'cleaned_text': 'كوباية الشاي والهاندفري مع أغنية يا بخت النوم بالدنيا وما '
#                  'فيها'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b36a'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'Mohamed44212659',
#  'cleaned_text': 'بعد سنة رجعت انتقم منك هتدوق من نفس الكاس اللي انا شربت منه '
#                  'بس انا بقرف ثواني اجيب كوباية تانية'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b36b'),
#  'cleaned_geo': 'Somewhere',
#  'cleaned_name': 'Sattamuni',
#  'cleaned_text': 'وده طبعاً عشان السكر بيلغي طعم أي حاجة تانية زي مانتوا '
#                  'عارفين. حط سكر في القهوة بقت كوباية مية بسكر.'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b36c'),
#  'cleaned_geo': 'Damitte',
#  'cleaned_name': 'barfii14',
#  'cleaned_text': ': الجو دا محتاج لحاف تقيل و كوباية نسكافيه و تكلم شخص بتحبه '
#                  'و بس كدة.'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b36d'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'md_boss49',
#  'cleaned_text': 'لسه كوباية القهوة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b36e'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'yasmeensamy',
#  'cleaned_text': 'اخر كوباية قهوة واخر ذرة كافيين واخر صوت منبه لمده اسبوع '
#                  'مثلا'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b36f'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'IKha496',
#  'cleaned_text': 'محتاج جدا امشي بلا هدف و معايا كوباية نسكافية كبيرة جدا سخنة '
#                  'و صوت فيروز و ياسلام لو على الكورنيش'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b370'),
#  'cleaned_geo': 'Unfortunately Egypt',
#  'cleaned_name': 'Meukc',
#  'cleaned_text': ': وده طبعاً عشان السكر بيلغي طعم أي حاجة تانية زي مانتوا '
#                  'عارفين. حط سكر في القهوة بقت كوباية مية بسكر.'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b371'),
#  'cleaned_geo': 'هما قالولك فين',
#  'cleaned_name': 'MaNOoN114',
#  'cleaned_text': ': كسر كوباية م النيش'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b372'),
#  'cleaned_geo': 'La La land',
#  'cleaned_name': 'Eman_Elwahsh',
#  'cleaned_text': 'اللي اتكسر جوايا مج مش كوباية'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b373'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'NescafeArabia',
#  'cleaned_text': 'إستهدي بالله برضوا، وإعمليلك كوباية نسكافيه وكلي معها كتكات '
#                  'ترويق وإسمعي دقات ️'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b374'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'TokaAyman98',
#  'cleaned_text': 'أقصى آمالي حاليًا عشان أنا شخص بيتوتي بالدرجة الأولى كوباية '
#                  'شاي سخنة ولب أسمر وأفلام حلوة ع اللاب وهدووووء من غير مذاكرة '
#                  'وصحيان من غير منبه'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b375'),
#  'cleaned_geo': 'Suez, Egypt',
#  'cleaned_name': 'AnasHamdyy',
#  'cleaned_text': 'بحس نهايتي هتكون علي ايد كوباية قهوة حقيرة..'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b376'),
#  'cleaned_geo': 'samesomamo7sin.com',
#  'cleaned_name': 'saloma59875579',
#  'cleaned_text': ': *ماما انا أخدت كوباية من النيش*.. -...'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b377'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'yassmintaskar',
#  'cleaned_text': 'ما افسده العالم يصلحه كوباية شاي و كتاب حلو و الله'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b378'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'YasmiineMounir',
#  'cleaned_text': 'انضم ليهم كوباية ليمون و عسل'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b379'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'docdonia',
#  'cleaned_text': 'ماما حلفت عليا ما انا جايبة قهوة وعملتي ايه ?? كوباية شاي '
#                  'اشربها من الصبح اهو وحاجة منتهي التخلف'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b37a'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'A7medM7moud74',
#  'cleaned_text': 'طبيعي معرفهاش ده انا اغلي حاجه شربتها كوباية سحلب وصاية ب9 '
#                  'جنيه وكنت عايز اتصور جنبها'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b37b'),
#  'cleaned_geo': 'دولة البوكيمون',
#  'cleaned_name': 'aia_gomaa',
#  'cleaned_text': ': اثبتت الدراسات العلميه ان اسرع طريقه للنوم هي كوباية '
#                  'نيسكافيه .'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b37c'),
#  'cleaned_geo': 'Maadi',
#  'cleaned_name': 'Husse3n',
#  'cleaned_text': 'من ساعة ماعرفت ان باكت النسكافيه الجولد بيتعمل في كوباية '
#                  'خمسينة مش مج حياتي اتغيرت للأحسن'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b37d'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'NonoNon99981843',
#  'cleaned_text': ': الواحد بقى يكسل لدرجة انه مبقاش يخبط علي كوباية الشاي بعد '
#                  'ميقلبها'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b37e'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'kweider_fox',
#  'cleaned_text': 'لو قدامي كوباية شاي بلبن ب خمسين جنية هجيبها'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b37f'),
#  'cleaned_geo': 'None',
#  'cleaned_name': '_1fai',
#  'cleaned_text': 'هعمل كوباية شاي واتفرج عليك'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b380'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'AhmedNa64986600',
#  'cleaned_text': 'تعال اعملك احلي كوباية'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b381'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Mohamed36097831',
#  'cleaned_text': 'بعد سنة رجعت انتقم منك هتدوق من نفس الكاس اللي انا شربت منه '
#                  '=بس أنا بقرف _ثواني اجيب كوباية تانية'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b382'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Mohammed942249',
#  'cleaned_text': 'ميبقاش ورايا كليه تاني يوم قاعده ف البلكونه مع كوباية شاي '
#                  'ويا سلام بقا لو soundtrack بت…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b383'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'Himty215',
#  'cleaned_text': 'قد يحزنك العالم و تسعدك كوباية سحلب بالمكسرات .'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b384'),
#  'cleaned_geo': 'وينترفيل',
#  'cleaned_name': 'Ahmed_Mogha',
#  'cleaned_text': '- عاملك كوباية شاى بقى من اللى مات ابوها = *بيطبطب على '
#                  'الكوبايه*'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b385'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'HebatAllah_Ali',
#  'cleaned_text': 'حطيت ايدي في كوباية الشاي بدل الطبق و مافيش بربع جنية تركيز '
#                  '🤦'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b386'),
#  'cleaned_geo': 'بيتنا',
#  'cleaned_name': 'wal7d_sayed',
#  'cleaned_text': 'قد يُحزنك العالم و يسعدك كوباية سحلب مثلا'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b387'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Nourhann22',
#  'cleaned_text': 'النهاردة كوباية القهوة وقعت و مكنتش لسه شربت منها بوق حتى '
#                  'وكنت عايزة أبكى على البن المسكوب حرفيا يعنى🤚'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b388'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'elnggar_saeed',
#  'cleaned_text': ': تفضلوا تتريقوا ع الستات وتقولولهم بتعملوا إيه! تدخلوا '
#                  'المطبح تولعوا في نفسكوا عشان تعملوا كوباية شاي'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b389'),
#  'cleaned_geo': 'في ارض الحكومة',
#  'cleaned_name': 'RehammAlaa',
#  'cleaned_text': ': الاكل اللي في الفرن ومغطياه بفويل ومش بيتفتح في بعد حبة ده '
#                  'ببقى هاين عليا ادخل اقعد معاه اشوفه عايز يتقلب، يتزود شوية '
#                  'ميه، كوبا…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b38a'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'yaSooo_m',
#  'cleaned_text': 'وهتضحي ب خمسة جنيه ي متهور!'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b38b'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'Ibrahim11929235',
#  'cleaned_text': 'كوباية شاي وسيجارة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b38c'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'cayoglufbf',
#  'cleaned_text': 'ساعات بتمني بس ابقي كوباية ️️'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b38d'),
#  'cleaned_geo': 'United States of Banisuef',
#  'cleaned_name': 'Mennabintessam',
#  'cleaned_text': 'حقيقي حقيقي حقيقي محتاجة متبرع يفكرني بمواعيد الدوا و لو '
#                  'مفهاش تعب يجيبلي الشريط و كوباية مية بالمرة .'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b38e'),
#  'cleaned_geo': 'Mansoura Dik',
#  'cleaned_name': 'saraEbrahem17',
#  'cleaned_text': ': اللى يكسر الكباية ويقرر يلزقها وكله أمل انه كمان هيشرب '
#                  'منها ميحاولش بقى يحط كمان مية سخنة جواها! عشان دى مش بس '
#                  'هتتك…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b38f'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Hossam102299',
#  'cleaned_text': 'كوباية شاى وسندوتشين كده وسمى الله واقعدى ذاكرى'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b390'),
#  'cleaned_geo': 'sharkia_fakous',
#  'cleaned_name': 'saraelahmady7',
#  'cleaned_text': 'ثوانى ادخل احلب الجاموسه واحيبلك كوباية لبن'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b391'),
#  'cleaned_geo': 'sharkia_fakous',
#  'cleaned_name': 'saraelahmady7',
#  'cleaned_text': 'ثوانى ادخل احلب الجاموسه واجيبلك كوباية لبن'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b392'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'mon3em96',
#  'cleaned_text': 'بس ادوني كوباية شاي طعمه حلو جاي من الكاميرون كتر خيرهم '
#                  'والله ولاد حلال وربنا يجيب لهم ابنهم بالسلامة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b393'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'M7mdd_3del',
#  'cleaned_text': 'صحيت اتعشيت و شربت سجارة و كوباية الشاي، نرجع نكمل نوم بقي و '
#                  'نقفلهم ساعة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b394'),
#  'cleaned_geo': 'None',
#  'cleaned_name': 'kweider_fox',
#  'cleaned_text': ': وهتضحي ب خمسة جنيه ي متهور!'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b395'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'M7mdd_3del',
#  'cleaned_text': 'صحيت اتعشيت و شربت سجارة و كوباية الشاي، ارجع اكمل نوم بقي و '
#                  'اقفلهم ساعة'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b396'),
#  'cleaned_geo': 'الأعلانات على حسابي',
#  'cleaned_name': 'amoony_ta32',
#  'cleaned_text': ': قد يُحزنك العالم و يسعدك كوباية سحلب او القعده علي '
#                  'الكورنيش دلوقتي.'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b397'),
#  'cleaned_geo': 'Dubai, United Arab Emirates',
#  'cleaned_name': 'ladydalilla',
#  'cleaned_text': ': اكيد كنت بتروح كل يوم تشرب كوباية شاى مع الغفير بتاع '
#                  'الڤيلا وتسرسبه فى الكلام يا خلبوص زى افلام الابيض و الاسود '
#                  'كد…'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b398'),
#  'cleaned_geo': 'Mansoura',
#  'cleaned_name': 'm7md_ali55',
#  'cleaned_text': 'انا بينى وبين ابويا نفسه فلوس يافاطمه كوباية الشاى بعملها له '
#                  'بخمساية'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b399'),
#  'cleaned_geo': 'Muscat, Oman',
#  'cleaned_name': 'sokara_alharbi',
#  'cleaned_text': ': الفرق بينك وبين الغلطة كوباية قهوة اشربها وهتفوق فا مش '
#                  'هتغلط .. اعلان في الجون'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b39a'),
#  'cleaned_geo': 'Egypt',
#  'cleaned_name': 'Meryam_benyamin',
#  'cleaned_text': ': بحس نهايتي هتكون علي ايد كوباية قهوة حقيرة..'}
# {'_id': ObjectId('5a26dc22204c9e0253e6b39b'),
#  'cleaned_geo': 'الدور الرابع',
#  'cleaned_name': 'bebosobhy123',
#  'cleaned_text': 'يسقط العالم وتحيا كوباية الشاي بالنعناع'}

# %% [markdown]
# #### Create a reference to `my_eg_collection`

# %%
coll_ref_eg = tweets_db.my_eg_collection

# %%
coll_ref_eg.count()
# Out:
# 518

# %%
cursor_eg = coll_ref_eg.find()

cursor_eg

eg_sample_docs = list(cursor_eg)

# %%
eg_tweets = list(coll_ref_eg.find())

# %%
eg_sample_docs[:5]
# Out:
# [{'_id': ObjectId('5a26dc22204c9e0253e6b196'),
#   'cleaned_geo': 'None',
#   'cleaned_name': 'kamal',
#   'cleaned_text': 'أزاي أقول لك كنا زمان ... والماضي كان فى الغيب بكره واللي أحنا فيه دلوقت كمان ... ح يفوت علينا ولا ندري'},
#  {'_id': ObjectId('5a26dc22204c9e0253e6b197'),
#   'cleaned_geo': 'Egypt',
#   'cleaned_name': 'agabdelrehim',
#   'cleaned_text': 'هي آراء آه بس أزاي أجويرو منتهي يعني أمال لو مكنش الهداف التاريخي للسيتي و كل موسم اقل عدد من الاهداف…'},
#  {'_id': ObjectId('5a26dc22204c9e0253e6b198'),
#   'cleaned_geo': 'None',
#   'cleaned_name': 'ElsndubadE',
#   'cleaned_text': 'أنت صيني أزاي تقارن شادي بالخطيب ألي هو الوحيد ألي خد الكورة الذهبية من مصر وبشهادت الزملكاوي قبل الأ…'},
#  {'_id': ObjectId('5a26dc22204c9e0253e6b199'),
#   'cleaned_geo': 'None',
#   'cleaned_name': 'h_sawires',
#   'cleaned_text': 'أزاي الناس كانت بتغرد في الخمسينات قبل إختراع تويتر.'},
#  {'_id': ObjectId('5a26dc22204c9e0253e6b19a'),
#   'cleaned_geo': 'Egypt',
#   'cleaned_name': 'Hagerelmor',
#   'cleaned_text': 'التوينز اللي معاها كل الحلو والوحش والمصايب والاكل والفشل مش عارفه من غيرك كنت هعيش أزاي ربنا يخليكي ليا ومش تويته توصفك'}]

# %%
coll_ref_eg.count()
# Out:
# 518

# %%
eg_tweets_df = pd.DataFrame(eg_sample_docs)

# %%
eg_tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518 entries, 0 to 517
# Data columns (total 4 columns):
# _id             518 non-null object
# cleaned_geo     518 non-null object
# cleaned_name    518 non-null object
# cleaned_text    518 non-null object
# dtypes: object(4)
# memory usage: 16.3+ KB

# %%
eg_tweets_df.sample(6)
# Out:
#                           _id    cleaned_geo     cleaned_name  \
# 15   5a26dc22204c9e0253e6b1a5   Saudi Arabia       AbdullaFal
# 257  5a26dc22204c9e0253e6b297  International    mo7ammed_ali7
# 269  5a26dc22204c9e0253e6b2a3           None  MahaYou18761740
# 103  5a26dc22204c9e0253e6b1fd           طنطا     elfeky_manar
# 4    5a26dc22204c9e0253e6b19a          Egypt       Hagerelmor
# 426  5a26dc22204c9e0253e6b340          Egypt     basantehab98
#
#                                           cleaned_text
# 15   : أزاي كل مرة بنشوفكم فيها، بنحس كأنها أول مرة...
# 257  أنا الأسبوع دا So depressed لدرجة لو حد قالي ا...
# 269          حتي ازيك استخسرها مبيقولهاش .. يا ساتر ..
# 103  مرة شوية رز حبو يسلمو على مديرهم قالوله ازيك ي...
# 4    التوينز اللي معاها كل الحلو والوحش والمصايب وا...
# 426  بتخانق مع ماما بتقولي ده انتي لو انا ميتة كده ...

# %%
eg_tweets_df['class'] = 'EG'

# %%
eg_tweets_df.sample(10)
# Out:
#                           _id                     cleaned_geo  \
# 304  5a26dc22204c9e0253e6b2c6                            None
# 45   5a26dc22204c9e0253e6b1c3                   Milano, Italy
# 22   5a26dc22204c9e0253e6b1ac                            None
# 162  5a26dc22204c9e0253e6b238                        في بيتنا
# 465  5a26dc22204c9e0253e6b367                           Egypt
# 269  5a26dc22204c9e0253e6b2a3                            None
# 232  5a26dc22204c9e0253e6b27e                            None
# 362  5a26dc22204c9e0253e6b300                 الأسكندرية, مصر
# 164  5a26dc22204c9e0253e6b23a                            None
# 83   5a26dc22204c9e0253e6b1e9  El Monofia, Egypt shebin Elkom
#
#         cleaned_name                                       cleaned_text class
# 304   moustafakamelm                             : ازيك مصطفي صباحك فل️    EG
# 45    Rose_Hime_Sama  : ها ها ها هاااي أزاي أأجدع تقول الكلام ده ، ط...    EG
# 22        Ejal3mrii0  : اللي شُفته قبل مَا تشوفك عينيًّا عُمْر ضايع ...    EG
# 162    Eman_Batoot35  : أشده من قفاه واقوله ازيك الجراءة حلوة مفيش كلام    EG
# 465          LeMasry  استهدي بالله كدة و اعمليلك كوباية نسكافية و اق...    EG
# 269  MahaYou18761740          حتي ازيك استخسرها مبيقولهاش .. يا ساتر ..    EG
# 232    hamdigharaibh  : مره شويه رز حبو يسلمو على مديرهم قالولو ازيك...    EG
# 362        ABDOU6012                                 حقولك ازيك من قلبى    EG
# 164  nGjOVhxZdbqgeNU  ازيك ياعمرو باشا انا ضياء البنا محاسب مقيم في ...    EG
# 83    SarahKhattab13                               ازيك يا يارا عامل اه    EG

# %% [markdown]
# ### Explore the `my_gulf_collection` collection

# %%
for a in tweets_db.my_gulf_collection.find():
    pprint.pprint(a)
# Out:
# {'_id': ObjectId('5a262b644be1040194a797d3'),
#  'cleaned_geo': {'102': 'Dubai, United Arab Emirates',
#                  '105': 'Kuwait',
#                  '113': 'Madrid , Milan',
#                  '114': 'Kuwait',
#                  '117': 'Saudi Arabia',
#                  '121': 'Lost',
#                  '125': 'Kuwait',
#                  '127': 'Kuwait',
#                  '128': 'البحرين',
#                  '131': '🇰🇼 | 🇬🇧',
#                  '133': 'None',
#                  '136': 'None',
#                  '137': 'Kuwait',
#                  '139': 'Kuwait',
#                  '140': 'Fullerton, CA',
#                  '141': 'Kuwait',
#                  '142': 'Kuwait',
#                  '143': 'Kuwait',
#                  '145': '+965 - CaiRo',
#                  '147': 'ديرة الكافيهات',
#                  '148': 'ديرة الكافيهات',
#                  '157': 'Kuwait',
#                  '158': 'Kuwait',
#                  '159': 'Kuwait',
#                  '161': '"',
#                  '162': 'None',
#                  '164': 'Kuwait',
#                  '167': 'None',
#                  '168': 'Kuwait/ Maroc',
#                  '17': 'None',
#                  '170': 'الرياض,',
#                  '172': 'Kuwait',
#                  '174': 'Kuwait',
#                  '175': 'None',
#                  '178': 'None',
#                  '18': 'Kuwait',
#                  '180': 'None',
#                  '181': 'None',
#                  '183': 'في عيونه',
#                  '187': 'Kuwait',
#                  '188': 'None',
#                  '191': 'Kuwait',
#                  '192': 'Kuwait',
#                  '193': 'Muharraq - Bahrain',
#                  '195': 'Bahrain',
#                  '197': 'Kuwait',
#                  '198': 'Kuwait',
#                  '200': 'Kuwait',
#                  '201': 'Kuwait',
#                  '202': '+973',
#                  '203': 'Kuwait - Bahrain',
#                  '204': 'Kuwait',
#                  '205': 'None',
#                  '206': "Aum'er\u200d️",
#                  '207': 'Al Qusour, Kuwait',
#                  '208': 'Kuwait',
#                  '209': 'Kh.',
#                  '211': 'None',
#                  '212': 'Kuwait',
#                  '213': 'None',
#                  '214': 'None',
#                  '215': 'None',
#                  '216': 'None',
#                  '217': 'Lekuwait •',
#                  '218': 'Kuwait',
#                  '219': 'None',
#                  '22': 'None',
#                  '220': 'None',
#                  '221': 'Kuwait | B',
#                  '222': 'Qatar🇶🇦',
#                  '223': 'None',
#                  '224': 'None',
#                  '225': 'Abdulla Al Salem, Kuwait',
#                  '226': 'AUM',
#                  '227': 'None',
#                  '228': 'سلطنة عمان العظيمة\u2066🇴🇲\u2069',
#                  '229': 'None',
#                  '230': 'Kuwait',
#                  '231': 'None',
#                  '232': 'Kuwait',
#                  '233': ':24ص',
#                  '234': 'الكويت فوق كل بيت !!',
#                  '235': 'Kuwait',
#                  '236': 'صحار, سلطنة عمان',
#                  '237': 'None',
#                  '238': 'None',
#                  '239': 'kuwait ~ Bahrain',
#                  '240': 'Doha, Qatar',
#                  '242': 'None',
#                  '243': 'None',
#                  '244': 'None',
#                  '247': 'None',
#                  '248': 'Kuwait',
#                  '250': 'Kuwait',
#                  '251': 'None',
#                  '252': 'None',
#                  '253': 'INTP',
#                  '254': 'Kuwait',
#                  '255': 'Hogwarts',
#                  '256': 'سيــدة اعمـال',
#                  '257': 'None',
#                  '258': 'الشمري .',
#                  '259': 'None',
#                  '26': 'Konoha',
#                  '261': 'Arabian Gulf',
#                  '263': 'None',
#                  '265': 'None',
#                  '266': 'Kuwait',
#                  '268': 'الكويت وطن النهار',
#                  '270': 'Kuwait',
#                  '271': 'Dream world',
#                  '273': 'الله ثم الوطن ثم رئيس الدولة',
#                  '274': 'Kuwait',
#                  '275': 'سأكون حيثما قلبي يكون',
#                  '276': 'Kuwait',
#                  '278': 'None',
#                  '279': 'Kuwait',
#                  '280': 'Kuwait',
#                  '281': 'None',
#                  '282': 'None',
#                  '283': 'في قلب أمي الحبيبة',
#                  '287': 'None',
#                  '288': 'Al Adailiya, Kuwait',
#                  '289': 'None',
#                  '292': 'None',
#                  '293': 'Kuwait',
#                  '294': 'Kuwait',
#                  '295': 'Kuwait',
#                  '296': 'kuwait/M.K',
#                  '297': "اللهمّ أُمــي'",
#                  '298': 'None',
#                  '299': 'None',
#                  '30': 'None',
#                  '300': 'None',
#                  '301': 'الجهرا الچبيره',
#                  '303': 'None',
#                  '304': 'redbull+mutreef',
#                  '306': 'None',
#                  '307': 'ما اشوف الخاص',
#                  '308': 'None',
#                  '309': 'Kuwait',
#                  '310': 'قلب الإنسانية',
#                  '311': 'None',
#                  '312': 'None',
#                  '313': 'عالمي دونك صغير',
#                  '314': 'None',
#                  '315': 'None',
#                  '316': 'بعيدة عن المنال',
#                  '317': 'None',
#                  '318': 'Kuwait',
#                  '319': 'Kuwait',
#                  '320': 'Kuwait',
#                  '321': 'Kuwait',
#                  '322': 'Kuwait',
#                  '323': 'miles away',
#                  '324': 'None',
#                  '325': 'None',
#                  '326': 'Kuwait',
#                  '327': 'الأمارات& دبي دار الحي',
#                  '328': 'None',
#                  '329': 'الشمري.',
#                  '330': 'Kuwait | LosAndalous',
#                  '331': 'None',
#                  '332': 'None',
#                  '333': "J'245",
#                  '334': 'ابيع لكم السمج بالماي',
#                  '335': 'Kuwait',
#                  '336': 'Kuwait',
#                  '337': 'Kuwait',
#                  '338': 'None',
#                  '339': 'Kuwait',
#                  '34': 'None',
#                  '340': 'Egypt .. Kuwait',
#                  '341': 'None',
#                  '343': 'None',
#                  '344': 'Kuwait .. ɪкαяυѕ',
#                  '345': 'الفيحاء, دولة الكويت',
#                  '348': 'وطنُـ النــهار +965',
#                  '35': 'None',
#                  '350': 'Kuwait',
#                  '351': 'بلدي الكويت',
#                  '352': 'دولة الكويت-الفيحاء',
#                  '353': 'آلَكــوٌيــتـ',
#                  '37': 'Kuwait',
#                  '39': 'upside down',
#                  '42': 'None',
#                  '46': 'مراح الوالد',
#                  '48': 'Hateen',
#                  '51': 'Kuwait',
#                  '52': 'None',
#                  '53': 'قيثارة الشّرق',
#                  '55': 'None',
#                  '6': 'United Arab Emirates',
#                  '66': 'None',
#                  '67': 'None',
#                  '68': 'None',
#                  '7': 'Dokhaa',
#                  '76': 'Kuwait',
#                  '78': 'Kuwait',
#                  '8': 'None',
#                  '80': 'Kuwait',
#                  '82': 'Kuwait',
#                  '83': 'Kuwait',
#                  '89': 'None',
#                  '97': 'Saudi Arabia',
#                  '98': 'Saudi Arabia',
#                  '99': 'ديرة الكافيهات'},
#  'cleaned_name': {'102': 'zayynzeyad',
#                   '105': 'mhseen11',
#                   '113': 'Eal213',
#                   '114': 'Fahad_alenze',
#                   '117': 'Var5ne',
#                   '121': 'paulsmith_66',
#                   '125': 'Caramella93S',
#                   '127': 'HKBMDH77',
#                   '128': '_m7md18',
#                   '131': 'alka__96',
#                   '133': 'om_saad_0',
#                   '136': 'shosha1q',
#                   '137': 'm_memoshi',
#                   '139': 'Alluremore',
#                   '140': 'akona__',
#                   '141': 'Y_BoHaza3',
#                   '142': 'mi3ado_1989',
#                   '143': 'mi3ado_1989',
#                   '145': 'Moodinoo',
#                   '147': 'savagecoffe_t',
#                   '148': 'savagecoffe_t',
#                   '157': 'Fahad_alenze',
#                   '158': 'RienMieuxQueMoi',
#                   '159': 'Physio_ALBatoul',
#                   '161': 'Z64x_m',
#                   '162': 'ilulwaa06',
#                   '164': 'white_pearla',
#                   '167': 'Efalajmix',
#                   '168': 'alaashobbar',
#                   '17': 'hodaaa_q8',
#                   '170': 'bander9910',
#                   '172': 'fawaz',
#                   '174': 'mmutairi_95',
#                   '175': 'alfaskara2016',
#                   '178': 'maidaltalhi',
#                   '18': 'DzY9d',
#                   '180': 'moody13_',
#                   '181': 'MubarkAlkhatlan',
#                   '183': 'o0om_meemy',
#                   '187': 'Redamo7amed7',
#                   '188': 'MOoON9q',
#                   '191': 'Nora_buhamad',
#                   '192': 'Nora_buhamad',
#                   '193': 'muharraq77',
#                   '195': 'il7mady',
#                   '197': 'DIOR911',
#                   '198': 'Fahad_alenze',
#                   '200': 'mbeeyaa',
#                   '201': 'Fahad_alenze',
#                   '202': 'dalsubaiee37',
#                   '203': 'Masha3ell_',
#                   '204': 'H477xx',
#                   '205': '_emanalr',
#                   '206': 'Al223a_',
#                   '207': 'samf16x',
#                   '208': 'saron_ashkanazi',
#                   '209': 'k566_x',
#                   '211': 'Abas22944447',
#                   '212': 'al_mousawi1',
#                   '213': 'rounie47',
#                   '214': 'ya_qc',
#                   '215': 'BatoolALQ_',
#                   '216': 'BatoolALQ_',
#                   '217': '__Danti',
#                   '218': 'mariam__214',
#                   '219': 'Alhuwaidi93',
#                   '22': 'ZuSX6cXU62tZPUW',
#                   '220': 'al3baidly656',
#                   '221': 'JayAltayeb',
#                   '222': 'Jazyyyy_',
#                   '223': 'abowaled_91',
#                   '224': 'sarasaladwani',
#                   '225': 'Rkaram56',
#                   '226': 'aumSuppoort',
#                   '227': 'sweara84',
#                   '228': 'Sa95d',
#                   '229': 'bo__ya3ga69',
#                   '230': 'ShrShr46333814',
#                   '231': 'AishaSalem77',
#                   '232': 'almotirihathlol',
#                   '233': 'r_kwtt',
#                   '234': 'majed9064',
#                   '235': 'al3nzeya94',
#                   '236': 'N3d72UsEjxVbhU',
#                   '237': 'Q_aljohra',
#                   '238': 'HAMADDDDDDD',
#                   '239': 'Drema111',
#                   '240': 'y_albadr',
#                   '242': 'Ai2x1',
#                   '243': 'a_bunashi',
#                   '244': 'elnoori31475',
#                   '247': 'four77x',
#                   '248': 'dymaker_',
#                   '250': 'q8princes78',
#                   '251': 'alamaken10',
#                   '252': 'alsaleh1954',
#                   '253': 'faalajmi3_',
#                   '254': 'fahadalroubah',
#                   '255': 'AALMx',
#                   '256': 'queen_380',
#                   '257': 'asad10917',
#                   '258': 'f5lx3',
#                   '259': 'Gxxu_',
#                   '26': 'R__Aey',
#                   '261': 'bkayfy',
#                   '263': 'Maysonalsaleh84',
#                   '265': 'InfoQ84ever',
#                   '266': 'piccadailly',
#                   '268': 'bo_3li_',
#                   '270': 'gh_alhashmi',
#                   '271': 'juman_562',
#                   '273': 'HKHALAWI',
#                   '274': 'hebaalroumi',
#                   '275': 's_altaher28',
#                   '276': 'ha8tt',
#                   '278': 'eng_wanni',
#                   '279': 'MaherAlMalalha',
#                   '280': 'isarah72',
#                   '281': 'omjasem23',
#                   '282': 'daandoon14',
#                   '283': 'LawyerKuwaitya',
#                   '287': 'hanina82',
#                   '288': 'Mryiaam',
#                   '289': 'mayssa_ms',
#                   '292': 'yn6li',
#                   '293': 'Nora_buhamad',
#                   '294': 'Nora_buhamad',
#                   '295': 'HK_AlRashed',
#                   '296': 'hassanjasim',
#                   '297': '_i9xr',
#                   '298': 'sa3d_f16_',
#                   '299': 'qb2xQpbikPCGyMO',
#                   '30': 'almutairi43__',
#                   '300': 'Omkhalifa4',
#                   '301': 'sn2ru',
#                   '303': 'om_zeena_93',
#                   '304': 'N657_V',
#                   '306': 'abee_y',
#                   '307': 'm0o0ooon',
#                   '308': 'MmrMmr41',
#                   '309': 'OmBadeer_78',
#                   '310': 'f_faten78',
#                   '311': 'Alhouti85',
#                   '312': 'ia267x',
#                   '313': 'MHA25_',
#                   '314': 'abdullah282851',
#                   '315': 'Malakii_5',
#                   '316': 'TeacherQ86',
#                   '317': 'mazajiq8i',
#                   '318': 'ghadoooor_',
#                   '319': 'h73849092',
#                   '320': 'Rawoony_',
#                   '321': 'baadryaa',
#                   '322': 'abotalal71',
#                   '323': 'ws_alshammarii',
#                   '324': 'h_hhhq8',
#                   '325': 'sheikha_732',
#                   '326': 'ManayerAlMuhtab',
#                   '327': 'Alali55sultan',
#                   '328': 'almohallabkw',
#                   '329': 'itsawrad2',
#                   '330': 'Goldeen_Girl',
#                   '331': 'S_jj_D_S',
#                   '332': 'DeviantFatma',
#                   '333': 'jal3wdhi',
#                   '334': 'jmbaaze',
#                   '335': 'mahmoud4325',
#                   '336': 'al_9ager727',
#                   '337': 'lulwaalawadhi',
#                   '338': 'a__',
#                   '339': 'freehanan197559',
#                   '34': 'skullxcrusherx',
#                   '340': 'faersn',
#                   '341': 'ghzlan12345',
#                   '343': 'HifaaYousef',
#                   '344': 'moona95',
#                   '345': 'aljaddah_kw',
#                   '348': 'Babo_oshA',
#                   '35': '_Alsh67',
#                   '350': 'yesandyes94',
#                   '351': 'ilsotiljare7',
#                   '352': 'AmSara75',
#                   '353': 'A6aif',
#                   '37': '_fatmaa114',
#                   '39': 'ig47j',
#                   '42': 'f36s_x',
#                   '46': 'mle3_al8eem',
#                   '48': 'B_aljenae',
#                   '51': 'NafNoof',
#                   '52': 'Ha2928',
#                   '53': 'alnweiam',
#                   '55': 'subzoe',
#                   '6': 'typicallynorah',
#                   '66': 'aIshoq',
#                   '67': 'almahdi__f',
#                   '68': 'Rel211_',
#                   '7': 'Hasan95780025',
#                   '76': 'Fahad_alenze',
#                   '78': 'albraikiq8',
#                   '8': 'FathiyaAjlan1',
#                   '80': 'Fahad_alenze',
#                   '82': 'albraikiq8',
#                   '83': 'Fahad_alenze',
#                   '89': 'wael_alyaseen',
#                   '97': 'hadeelnasser34',
#                   '98': 'hadeelnasser34',
#                   '99': 'savagecoffe_t'},
#  'cleaned_text': {'102': 'أقسم بالله لو صايرة قدامي لا ابركن عجمب و اتفرج عل '
#                          'منظر و أدخن والله روعة',
#                   '105': 'اتمنى مناقشة طريج الوفرة تعبنا من الطريج',
#                   '113': 'ما انسى هاليوم',
#                   '114': ': ما انسى هاليوم',
#                   '117': 'وش هذا',
#                   '121': 'وقتها تذكرون شنو صار',
#                   '125': 'غثني هذا الي يصور حييييل يقول دشها وروح وماعليك ولن '
#                          'يصيبنا إلا ما كتب الله لنا، بالله كان شي خطير يومها '
#                          'ومسوي فيها…',
#                   '127': 'الحين أمرج مسافه الطريج',
#                   '128': 'انا كنت ناوي جذي بس انتهى فيني الطريج عند كرك '
#                          'السبعينات ف بوكواره',
#                   '131': 'من صجج احس بينزلني بنص الطريج',
#                   '133': 'لا قمته بعد اليوم بقول مثل و مو حافظته الطريج الي '
#                          'يودي و مادري شنو',
#                   '136': '…',
#                   '137': ': من صجج احس بينزلني بنص الطريج',
#                   '139': 'مشاري خايف بس صاحبه مادري شعنده',
#                   '140': 'زحمة والطريج شبه واقف إطقين هرنات علشان يمشي الطريج '
#                          'جد والله ؟!!! صجج حريييم',
#                   '141': 'يومها واحد من الربع رايح المزرعة عنده رانجلر كشف '
#                          'شايل البيبان والسقف واهو رايح يشوف هالغبار جدامه '
#                          'وعادي دايس وقاعد…',
#                   '142': 'لا يوجد احد في هذا العالم اصبح غنيا بالعمل من صباحا '
#                          'حتى مساء ! ابحثو عن عمل غير هذا العمل .. تاجر '
#                          'المخدرات بابل…',
#                   '143': 'يالله يا جماعة دلونا الطريج \u200d️',
#                   '145': 'الصليبية',
#                   '147': ': مشاري خايف بس صاحبه مادري شعنده',
#                   '148': ': يومها واحد من الربع رايح المزرعة عنده رانجلر كشف '
#                          'شايل البيبان والسقف واهو رايح يشوف هالغبار جدامه '
#                          'وعادي دايس وقاعد…',
#                   '157': ': غثني هذا الي يصور حييييل يقول دشها وروح وماعليك '
#                          'ولن يصيبنا إلا ما كتب الله لنا، بالله كان شي خطير '
#                          'يومها ومسوي فيها…',
#                   '158': 'عبده التصوير',
#                   '159': 'شلون جذي صار بليل !! والسيارات على كيفهم يغيرون الخط '
#                          'دشوا الخط الثاني زين',
#                   '161': 'مضيع الطريج حبيبي',
#                   '162': 'ف الطريج',
#                   '164': 'عيل احسنلج من دعالتهم اهما اختصروا الطريج',
#                   '167': 'اغنية الطريج الطويل :',
#                   '168': 'اخاف اليوم smiling day وانا مضيعه الطريج !!! شفيكم '
#                          'علي',
#                   '17': 'اوك مسافة الطريج يايتلچ \u200d️\u200d️\u200d️',
#                   '170': 'الطريج',
#                   '172': 'علمّوا من فيه غلٍ على شعوب الخليج الخليج موحّد الصف '
#                          'بقيادة صباح كل ما ضاقت عليه يبوج إلها الطريج واقفٍ '
#                          'من دونه…',
#                   '174': 'وييع عاد الحين الطريج سااعه',
#                   '175': 'وشدعوه ماسووها ايام الطردي بالشوراع واقتحموا المناطق '
#                          'السكنيه ‼️بعضهم حتى الطريج مايدله ‼️',
#                   '178': ': ️ خاطري طاب من ذاك الفريج صد قلبي وانا تابع هواه '
#                          'كل يوم وانا أدق الطريج ماأحْدٍ قال…',
#                   '18': 'كلام جميل لكن وين التطبيق.طلع قانون للخدم ونشر '
#                         'بالجريدة الرسمية من زمان وللحين احنا ناطرين ا…',
#                   '180': ': علمّوا من فيه غلٍ على شعوب الخليج الخليج موحّد '
#                          'الصف بقيادة صباح كل ما ضاقت عليه يبوج إلها الطريج '
#                          'واقفٍ من دونه…',
#                   '181': 'ما اكلم الدكاترة يغيرون درجتي .. واخذته درس لا تايس '
#                          'بنص الطريج شد حيلك للاخير',
#                   '183': 'لا وصلت ل احكم توك بدايه الطريج',
#                   '187': ': شنو الفرق بين شوارع الكويت وشوارع الهند؟الهند عادي '
#                          'تشوف بقرة تمشي وتقطع عليك الطريج اهني البقرة بكبرها '
#                          'تسوق السيارة',
#                   '188': 'ههههههه روح الطريج مفتوح',
#                   '191': 'اتمنى من الله العزيز الحبار انه يرزق اللي سمح '
#                          'للبقالات بيت في صباح الاحمد ويجرب الطريج',
#                   '192': 'اتمنى من الله العزيز الجبار انه يرزق اللي سمح '
#                          'للبقالات بيت في صباح الاحمد ويجرب الطريج مع البقالات',
#                   '193': ': يالله يا جماعة دلونا الطريج \u200d️',
#                   '195': 'وصلت نص الطريج و انكت علي اللبن',
#                   '197': 'هذا ينطبق عليه المثل : مشاري من أمامي والعاصفة من '
#                          'خلفي 🤣🤣 بس عجبني صملها يمثلني عند الاكشن',
#                   '198': ': هذا ينطبق عليه المثل : مشاري من أمامي والعاصفة من '
#                          'خلفي 🤣🤣 بس عجبني صملها يمثلني عند الاكشن',
#                   '200': 'ليش ما اذكر هل يوم ! اكيد كنت نايمه \u200d️',
#                   '201': ': ليش ما اذكر هل يوم ! اكيد كنت نايمه \u200d️',
#                   '202': 'كاني يايه ف الطريج',
#                   '203': 'اكثر شي ينرفز لمن اكون طالعه بروح كلاس و بنص الطريج '
#                          'تعتذر',
#                   '204': 'انا راضيه اتنرفز اذا جذي',
#                   '205': 'عندي مهارة مبكية بتطويل الطريج',
#                   '206': 'تأخرت على نومتي حبايبي خلاص سكرو الطريج اول مايمر '
#                          'الامير ماله داعي قبلها بنص ساعه',
#                   '207': 'اللي مسؤول عن التحويلات اللي عند شارع الغوص و ماك '
#                          'فلها شوي تكفا ضيعت الطريج مليون مره ( تقاطع القرين و '
#                          'القصور ال…',
#                   '208': 'الطريج ضيج وهي شمتنها تتمشى مع ربعها زين بمر أنا '
#                          'عنونه كتري خصرچ يسار شوي خل أطوف لاااا أبداً صعدتني '
#                          'رصيف آنا وجنطتي',
#                   '209': 'زهقت من الطريج كليوم رايح راد من ام الهيمان لي مبارك '
#                          'الكبير',
#                   '211': 'صدق من وصفكم بالطكعانيين…',
#                   '212': 'تستاهل الطيب يالحبيب مسافة الطريج بالوانيت جايك 🤣',
#                   '213': 'بنص الطريج الدكتور قال اليوم اوف اها',
#                   '214': 'مساء الطريج',
#                   '215': 'المزاج نول طول الطريج 🤦\u200d️',
#                   '216': 'المزاج نوال طول الطريج 🤦\u200d️',
#                   '217': 'ابد مسافة الطريج بس',
#                   '218': 'بحاول اعلم السايق على الطريج الي قلتيه',
#                   '219': 'طبعا قوقل ماب فايدة الاكبر اهي يحدد الزحمة ويعطيك '
#                          'الطريج الاسرع ، لكن لا يعطيك خدعووه',
#                   '22': 'الثالث علي الطريج طولي بالج اول الله️',
#                   '220': 'راح انتقل لان الطريج بعيد بس ما ارد حواء ️',
#                   '221': 'شي أول مره اجربه: الحق دوريه عشان تفتح لي الطريج 🤣',
#                   '222': 'فنص الطريج استوعبت اني طالعه بالسلبر بصيح',
#                   '223': 'انتهت الجلسه وين البشرى والفرحه للأسف يبون الأمور '
#                          'على كيفهم تعديل القوانين خطوه جيده وتحسب للمجلس طيب '
#                          'عودة اللجا…',
#                   '224': 'اهل الفحيحيل اولى عشان نفضيلهم الطريج بعد',
#                   '225': 'موعد تغير القانون للفيفا هي اخر يوم غداً لكن قال '
#                          'خالد الروضان بان الخطوه الثانيه و الثال…',
#                   '226': 'عشان محد يقول مصكرين الطريج وماقدرت اداوم',
#                   '227': 'اقول شكله الصاروخ ضاع ماعرف الطريج',
#                   '228': 'البريمي هذي ونحن ف الطريج الى الامارات',
#                   '229': ': عشان محد يقول مصكرين الطريج وماقدرت اداوم',
#                   '230': 'بهذي عاد انا معاج علي طوووول الطريج مصدقج .. الله '
#                          'اعلم الي تتحضر قبل العيد بشهر وين تقضيه ههههههه',
#                   '231': 'بعده في الطريج واقف يشرب كرك',
#                   '232': 'خنسمع يلا الطريج واقف ماورانا شيء.',
#                   '233': 'نسيتي االنوطه خليتيها بروحها بنص الطريج قاسيه',
#                   '234': 'عسروج في معده عنز متوفيه صارلها إسبوع طايحه ع الطريج',
#                   '235': '+2 آمين أجمعين يارب _ بالنسبه لي عادي جدا و انا ما '
#                          'اكرهه مني و الطريج _ تسسلموون وين شايفيني',
#                   '236': ': صباح الونيس والتعيس للمغتربات لأنهم طول الْيَوْمَ '
#                          'ف الطريج والله يحفظنا وييسرلنا',
#                   '237': 'ولج اللي معاها حمارها حطتها بنص الطريج هههههههههههه',
#                   '238': 'تحول لي بدل الطريج مال الشهر الياي؟',
#                   '239': 'زين زين ادل الطريج من بيتنا للدوام ..شلون تسكرون '
#                          'الهاي وي عفيه! استحالة اخترع طريج جديد !تبون اوصل '
#                          'الحدود يعني!️',
#                   '240': 'في الطريج الظاهر ضربه الجوع.',
#                   '242': 'أي وطول الطريج أدعي عالي معطيج الليسن',
#                   '243': 'بخصوص سالفة أنهم بيصكرون الطريج يوم الثلاثه، انا ما '
#                          'راح يحوشني شي لاني ابلش الساعه واخلص الساعه باليل '
#                          'وانتو طح…',
#                   '244': 'عزيزتي البقرة لما الشارع رايح راد توقفين بنص الطريج '
#                          'عشان تنطرين مصفط توقعوا هرنات فلا تقعدين اتكمين كمج '
#                          'جني',
#                   '247': 'ايي "صايدها " مسوي نفسك فاهم و انت ما تدري شسالفة '
#                          'دايم تخلي الكلام كلة و ترد علي شي واحد و صدقني ما ر…',
#                   '248': 'اطالب بعطله مدرستي بمنطقه بعيده عني اصلا اطلع من '
#                          'البيت :٣٠ واوصل :٣٠ تقريبا مايصير اذا…',
#                   '250': 'الطريج مسكر نطلع الفجر يعني ؟!',
#                   '251': 'الطريج راح يسكرونه الساعه الصباح او بس',
#                   '252': 'ماشالله عليك قاعد لهم قعده وتعلمهم الطريج الصح '
#                          'والسهل لمواقفك المسانده للشباب الرياضي بس ﻻحياة لمن '
#                          'تنادي',
#                   '253': 'يلا مسافة الطريج بس',
#                   '254': 'تخيل تطلع من البيت وواقف الطريج وماتقدر تمسك تلفونك '
#                          'ولاتسوي شي',
#                   '255': 'انهرت ضيعت الطريج وصلت لي الجهرا ودقيت على ابوي '
#                          'وصلني لي البيت',
#                   '256': 'مسافة الطريج',
#                   '257': 'والله ورانا بصمه ومدارس والشوارع تتصكر هذا غير تغيير '
#                          'الطريج ،. ترى في ناس ما تدل مثلي',
#                   '258': 'بيصكون الطريج السريع الخامس و مادري شنو بعد حق '
#                          'المؤتمر امما انتو بتوع المدارس احذفكم چلوتي وصلتوا '
#                          'لمدارسكم .',
#                   '259': 'لي بيسكرون الطريج',
#                   '26': 'لما أكون مستعيله ويغلط السواق ف الطريج',
#                   '261': 'الصاروخ نزل استراحه عندنا يترس بنزين ويتعشى وتالي '
#                          'يكمل الطريج هههههه',
#                   '263': 'من زعلك؟بعيونك السود نظرة لا شفتها حسيت بالحزن '
#                          'بالياس🥀 من زعلك طاحت من الليل قمره…',
#                   '265': 'اسمعني عاد اقول لك يا .. . انت الذي اخترت الطريج '
#                          'وأشعلت في يوفي حريج أتركني في حالي وارحل على خير لا…',
#                   '266': 'والله السالك مو الطريج شي ثاني تحسسونا اننا شعب غبي '
#                          'والشوارع سالكه ومافي زحمه تلعبون علينا !!',
#                   '268': 'زين اذا الطريج من و الى المطار مسكر الساعه ليه ال٢ '
#                          'شلون نرد بيوتنا بقاري ولا النفق اللي تحت الارض !؟',
#                   '270': 'الطريج العادي من غير زحمه من نص ساعه الى ساعه الى '
#                          'ربع ، واحيانا بالرده ياخذ اكثر من ساعه الى ساعه ونص',
#                   '271': 'اذا الطريج اللي متعودة عليه للجامعة مسكر وحياتكم ارد '
#                          'البيت انام غياباتي موجودة',
#                   '273': 'ما اروم ... الطريج يضيّق الخْلق',
#                   '274': 'احس لما قوقل ماب يحط الطريج زحمه وده يقول هونيها و '
#                          'تهون',
#                   '275': 'اوصل الجامعة بعد طريج ساعة كاملة عشان دكتورة تشرح '
#                          'دقايق وبنت تنرفزها وتطلع من الكلاس ؟ انتي والبنت ما '
#                          'هميتوني بس…',
#                   '276': 'انا بفهم تسكرون الطريج في اوقات الذروه واهو بروحه '
#                          'زحمه من غير قمه عطلوا المدارس يوم واحد مايضر علشان '
#                          'مايطلع الا الم…',
#                   '278': 'خير اختي مضيعه الطريج !',
#                   '279': ': حياهم الله .. وان شاء الله تكون الأمور على ما أفضل '
#                          'مما نتوقع والمفروض عطلة رسميه لان الطريج بيصير Full '
#                          'إسوه…',
#                   '280': 'لما وصلت نص الطريج تعتذر؟؟؟؟؟؟؟؟',
#                   '281': 'لا لا حشا الطريج كله لك',
#                   '282': 'الطريج السالك هو اللي بتدش فيه سيارات الكويت كلها '
#                          'وماراح نوصل بيوتنا ليما المغرب بعد الساعه كالعاد…',
#                   '283': 'جزاك الله خير الله يحفظك بس ترى الطريج فاضي ومستحيل '
#                          'أعرض غيري للخطر لاتحاتي يالغالي وتسلم على حرصك',
#                   '287': 'ههههههههههههههههه مادل الطريج الثاني عدل +مالي خلق '
#                          'تعودت عليه',
#                   '288': 'ولا تشوفوووون حولي لما ادش حولي احس اني مواطنة '
#                          'كويتية مُهانه و مسلوب حقي الكل يطق بريك بويهي، فجأه '
#                          'يسفط و ينزل ب…',
#                   '289': 'يعني الساعه ليمه الساعه ياالله يفج الطريج يعني متي '
#                          'نبتي ناخذ اعيالنا نطلع الساعه نقعد ونوقف عند باب…',
#                   '292': 'أربّي بناتي على مسح أرضية الشقة، غسل ملابسهم ونشرها، '
#                          'تحضير الريوق كل ويك اند بدون أن ألتفت لتنهوصهم '
#                          'واعتراضهم الجا…',
#                   '293': 'للحد من الزحمة ترى يقدرون ينقلون الضيوف 🇰🇼🇴🇲🇶🇦🇸🇦🇦🇪🇧🇭 '
#                          'المطار للقصر ومن مكان لمكان عن طريق طائره مروحيه 🤗 ( '
#                          'هليكوبتر…',
#                   '294': 'للحد من الزحمة ترى يقدرون ينقلون الضيوف🇰🇼🇴🇲🇶🇦🇸🇦🇦🇪🇧🇭 '
#                          'المطار للقصر ومن مكان لمكان عن طريق طائره مروحيه 🤗 '
#                          '(هليكوبتر) ب…',
#                   '295': 'انا ساكنة في بيان ويم القصر ... اشلووون اروح الجامعة '
#                          'الطريج راح يكون مصكر',
#                   '296': 'توخو زحمة الطريج باجر',
#                   '297': 'ههههههههههههههههه توصلين بالسلامةة .. بلغي سللامي',
#                   '298': ': عزيزتي البقرة لما الشارع رايح راد توقفين بنص '
#                          'الطريج عشان تنطرين مصفط توقعوا هرنات فلا تقعدين '
#                          'اتكمين كمج جني',
#                   '299': ': اسمعني عاد اقول لك يا .. . انت الذي اخترت الطريج '
#                          'وأشعلت في يوفي حريج أتركني في حالي وارحل على خير لا…',
#                   '30': 'احبك كثر ماتوقف على جنب الطريج اشجار احبك كثر مايقسى '
#                         'الشتا وتهاجر طيوره..',
#                   '300': 'المفروض الكل يعطل . عندنا معلمات واداريات ايون من '
#                          'هالمناطق الداخلية واحنا بمبارك الكبير . شلون بيوصلون '
#                          'بالله اذا الطريج مسكر',
#                   '301': 'وتدرون شنو فايده السنقل بعد ؟ تحطين الاغنيه الي '
#                          'تعجبج بالسياره ( تشبكين بلوتوث ) بدون ازعاج مسجات '
#                          'وطمنيني وين وصلتي…',
#                   '303': 'بيسكرون الطريج عشان مؤتمر القمة',
#                   '304': 'كنت بالمقبره مع امي و اخوي عبالي بمووت',
#                   '306': ': انا صوت الفريج وبنتٍ تناديك تدليك الفرح وينه انا '
#                          'ثوبك وسبحةٍ في يدك واللي راح من عمرك انا اشيله أدليك '
#                          'الطريج اللي…',
#                   '307': 'انت شعلامك اذا ماكو خلوه معناته الحريم تتطلق وبعدين '
#                          'قضيه نفقه عده ومتعه وتكثر المطالبات قال انا اصك '
#                          'عليهم…',
#                   '308': 'الفروانيه المقصد مو المحافظه المنطقه لانه يم الطريج '
#                          'ويم خيطان',
#                   '309': 'انت ريال اشويه المسأله تخف عليك لكن احنا شوي صعب طول '
#                          'الطريج وغير الزحمه والمواجيب والمشاوير الضروريه',
#                   '310': 'انزين وبالنسبة حق موظفي هذه المناطق وين نروح لما '
#                          'يسكرون الشوارع مرة قعدت في بيت اصدقاء العائلة لين '
#                          'يفتحون الطريج !!…',
#                   '311': 'قبل يوم تسير مكان بعيد .. يوصونك على الدرب وهالله '
#                          'هالله في الطريج .. الحين يوصونك على الرادارات .. '
#                          'هالله هالله في…',
#                   '312': 'باجر الطريج مسكر وهالحمار معطينا امتحان؟ اقوله شلون '
#                          'نجي يقول بحنطور ياحلوك دمك ثقيل الله ياخذك',
#                   '313': 'لا راح اداوم بس انا على راسي ويشه يفتحون لي الطريج',
#                   '314': ': وتدرون شنو فايده السنقل بعد ؟ تحطين الاغنيه الي '
#                          'تعجبج بالسياره ( تشبكين بلوتوث ) بدون ازعاج مسجات '
#                          'وطمنيني وين وصلتي…',
#                   '315': 'يا داشه برصيف يامضيعه الطريج بارك الله فيني️',
#                   '316': 'عاد اشكثر جدامي في الطريج اشوفهم يقطون أعقاب الزقاير '
#                          'بس حسافة ما يمدي اصورهم',
#                   '317': 'ولاتنسى اللي يروحون الجامعات والتطبيقي كلهم يمرون من '
#                          'نفس الطريج',
#                   '318': 'من عاداتي وتقاليدي انسى كتابي بالجامعه وبنص الطريج '
#                          'اتذكر وارد اخذهثووله',
#                   '319': 'يايماعه الطريج بكره صوب حولي مسكر؟؟',
#                   '320': 'سلام عليكم دكتوره باجر ما راح اقدر احضر الشوارع '
#                          'مسكره وانا بيتنا بصباح الأحمد و الطريج الي ايي منه '
#                          'مسكر…',
#                   '321': 'ايييي والله لانه نفس الفكره الحين عطلو اللمدارس '
#                          'علشان الزحمه نفس السالفه الموظفين كلهم راح يتحهون '
#                          'بنفس ا…',
#                   '322': 'شاطره يا عطيات .... الوضع لا صواريخ ولا غيره من '
#                          'الواضح من قراءتي للأحداث انهم قطعوا عليه الطريج '
#                          'ونزلوه…',
#                   '323': 'الطريج اللي يكون اقل من دقايق عشان تشوفون احد من '
#                          'زمان مو شايفينه اطول طريج بالدنيا cousin aziz !!!!️',
#                   '324': 'دكاترتي بلييز بليييز اعتذروا احنا خلقة مانعرف نسوق '
#                          'هم بعد زحمة وهم مسكرين الطريج',
#                   '325': 'وشلون على الي بيوتهم بعيده من دواماتهم احنا من غير '
#                          'شي قاعدين نوصل متأخر هل مره بتصكون شو…',
#                   '326': 'ما لج إلا الدعاء🤦\u200d️ ان الطريج يكون مفتوح',
#                   '327': 'مانسلم علي خونه خذلك نص ديايه مكينه علي الطريج',
#                   '328': 'اللي انقتل شبيهه مثل ماقالوا عن الكاولي يوم اعدموه '
#                          'قالوا إللي انعدم شبيه .. صرنا محللين واحنا مان…',
#                   '329': 'لمن اطلع مع امي وخالتي ويكون الطريج طويل',
#                   '330': ': حدث في الكويت قبل جم سنه ،، لكن مو إهني المشكله ، '
#                          'المشكله الناس من الرعب كل السيارات طقت فوق تحت و '
#                          'عكست الطريج إلا…',
#                   '331': ': . . أخو يسجاد وطبعك هذا من هلك وأدري تكمل الطريج '
#                          'لو بيه هلاك جمايل يخوي فوگ الراس شايل…',
#                   '332': 'سووووعال الطريج حق شويخ باجر مثل كل يوم ولا؟',
#                   '333': ': اطالب بعطله مدرستي بمنطقه بعيده عني اصلا اطلع من '
#                          'البيت :٣٠ واوصل :٣٠ تقريبا مايصير اذا…',
#                   '334': 'مخيمنا ما يضيع بنص الطريج بين الشارعين تحت الشبه '
#                          'نرحب فيج وبكل رفيجاتج وخواتج ومعارفج يا هلا يا هلا',
#                   '335': 'الحين أنا أبي أعرف طلاب الجامعة يروحون بشنو مو '
#                          'بسيارة يعني أكيد راح تسكر الطريج عليهم اي والله احنا '
#                          'مان…',
#                   '336': 'محددين الطريج المصكر أنزين انا ساكن بالسلام ومدرستي '
#                          'بالروضه جي اقدر اوصل ولا مصكر؟🤔',
#                   '337': 'انتي قلبي اللي في قلبي و الطريج اللي بدربي "هيونتي"',
#                   '338': 'على حظج الخايس رحت نص الطريج شفت الزحمه وعطيتها فوق '
#                          'تحت ورديتباجر باجر معاج',
#                   '339': 'نعم الذنب على الوالدين خوفهم على نفسهم من الدوام '
#                          'والبصمة وضيعو العيال مع السواق وفِي الشوا…',
#                   '34': 'لحد يسلمي الAUX ويقولي بسج توقفين بنص الاغنيه, الطريج '
#                         'دقايق وانا عندي اغنيه بسمعها!',
#                   '340': 'جايز الطريج زحمه',
#                   '341': 'اخوان سته كلنا نمشي بنفس الطريج 🇦🇪️🇧🇭️🇸🇦️🇴🇲️🇶🇦️🇰🇼',
#                   '343': ': اخوان سته كلنا نمشي بنفس الطريج 🇦🇪️🇧🇭️🇸🇦️🇴🇲️🇶🇦️🇰🇼',
#                   '344': 'لما بابا يهد قضايا الشعب كلها ويقول انا بفهم شلون '
#                          'تطلعين قبل المحاضره بثلث ساعه وتقولين لي وصلت مبجر '
#                          '🤦\u200d️ ياخي الطريج سالك والله مو دايسه',
#                   '345': 'يارب الموكب السعودي يظيع الطريج ويچيور ويدش بالغلط '
#                          'الفيحه وبوطَة العاصمه عشان نعطل غصب',
#                   '348': 'مالي شغل بالدوام ابي الطريج اللي يودي مستشفى الصباح '
#                          'بس خلاص الصبح سالك اشوى',
#                   '35': 'انا نظامي اخليهم يسمعون اول دقايق والي بعده',
#                   '350': ': يارب الموكب السعودي يظيع الطريج ويچيور ويدش بالغلط '
#                          'الفيحه وبوطَة العاصمه عشان نعطل غصب',
#                   '351': 'انت الذي اخترت الطريج و أشعلت في يوفي حريق',
#                   '352': 'وليلحين معزم انه اغلب المدارس يعطلون يا كثر الدعاوي '
#                          'بتحصلها يا وزير التربيه .. بنطلع عيالنا قبل لا '
#                          'يسكرون الطريج عل…',
#                   '353': 'حطيلهم لافتات علي الشبات الشوارع خوفج يضيعون الطريج',
#                   '37': 'حدة حدة',
#                   '39': ': لحد يسلمي الAUX ويقولي بسج توقفين بنص الاغنيه, '
#                         'الطريج دقايق وانا عندي اغنيه بسمعها!',
#                   '42': 'ماشفت هالشي شنو هذا',
#                   '46': 'متعني للعاشره عشان اتقهوى يالله الخيره ماتحسفت الا '
#                         'يوم وصلت نص الطريج',
#                   '48': 'بنجر علي التاير بنص الطريج و رجعت بتكسي LIVE on',
#                   '51': 'ايي والله بغيت اغير طريجي والسبه اني مابي افتحله '
#                         'الطريج وداااايس',
#                   '52': ': انا نظامي اخليهم يسمعون اول دقايق والي بعده',
#                   '53': 'الطريج يخوف بليل',
#                   '55': 'الله يحييچ يلا مسافة الطريج وأكون عندچ',
#                   '6': ': على الاقل ارحم من ان تتعود على وجود احد ويغرقك '
#                        'اهتمام وحب ويغنيك عن الدنيا وبنص الطريج يخليك تعاني '
#                        'وتت…',
#                   '66': 'متعه في خط سريع فاضي بالليل ويمك غالي تحبه وبعد '
#                         'سوالفه تسمع طرب ابو نوره ودك الطريج يطول️ !',
#                   '67': 'شنو هذا ابي اعرف !!',
#                   '68': 'شلون جذي',
#                   '7': 'وحدة مكافحة الموز في الطريج',
#                   '76': ': شنو هذا ابي اعرف !!',
#                   '78': 'انزين الناس منحاشة لي وين هي جايتكم جايتكم',
#                   '8': 'انا صوت الفريج وبنتٍ تناديك تدليك الفرح وينه انا ثوبك '
#                        'وسبحةٍ في يدك واللي راح من عمرك انا اشيله أدليك الطريج '
#                        'اللي…',
#                   '80': ': انزين الناس منحاشة لي وين هي جايتكم جايتكم',
#                   '82': 'ريتويت اذا كان عبالك يوم القيامة',
#                   '83': ': ريتويت اذا كان عبالك يوم القيامة',
#                   '89': ': • خاطري طاب من ذاك الفريج صـد قلـبي وانـا تـابع '
#                         'هـواه • كل يوم وانا أدق الطريج ماأحد قـال لي وا…',
#                   '97': 'تقريباً كان قبل سنوات .. يوم مانساه!',
#                   '98': ': تقريباً كان قبل سنوات .. يوم مانساه!',
#                   '99': 'حدث في الكويت قبل جم سنه ،، لكن مو إهني المشكله ، '
#                         'المشكله الناس من الرعب كل السيارات طقت فوق تحت و عكست '
#                         'الطريج إلا…'}}
# {'_id': ObjectId('5a262bf24be1040194a797d4'),
#  'cleaned_geo': {'0': 'None',
#                  '1': 'بِدبِد - SQU - معبيلة سيتي',
#                  '10': 'None',
#                  '100': 'Saudi Arabia',
#                  '111': 'None',
#                  '114': 'Gaza',
#                  '115': 'None',
#                  '116': 'None',
#                  '119': 'Saudi Arabia',
#                  '12': 'None',
#                  '120': 'Saudi Arabia',
#                  '121': 'None',
#                  '125': 'Saudi Arabia',
#                  '126': 'None',
#                  '128': 'None',
#                  '13': 'None',
#                  '131': 'مومباي/ الهند',
#                  '133': 'None',
#                  '134': 'Saudi Arabia',
#                  '135': 'Saudi Arabia',
#                  '14': 'None',
#                  '142': 'None',
#                  '143': 'Saudi Arabia',
#                  '144': 'القصيم',
#                  '145': 'Saudi Arabia',
#                  '146': 'الرياض، جدة | دبي، أبوظبي',
#                  '148': 'مكة المكرمة, المملكة العربية السعودية',
#                  '149': 'Saudi Arabia',
#                  '150': 'None',
#                  '154': 'القصيم-الشماسية',
#                  '155': 'الدمام, المملكة العربية السعودية',
#                  '156': 'None',
#                  '157': 'Saudi Arabia',
#                  '158': 'None',
#                  '159': 'Saudi Arabia',
#                  '16': '',
#                  '160': 'In the middle of nowhere',
#                  '161': 'المدينة المنورة',
#                  '163': 'None',
#                  '164': 'None',
#                  '165': 'None',
#                  '166': 'Saudi Arabia',
#                  '167': 'Makkah Al Mukarrama, Kingdom of Saudi Arabia',
#                  '168': 'الخبر',
#                  '17': 'None',
#                  '170': 'لقائنا في الجنة بإذن الله',
#                  '171': 'Saudi Arabia',
#                  '175': 'ينبع الهويّة والهوى',
#                  '176': 'Maßbach, Deutschland',
#                  '180': 'None',
#                  '186': 'None',
#                  '187': 'Saudi Arabia, Riyadh',
#                  '190': 'مومباي/ الهند',
#                  '191': 'Libya',
#                  '192': 'Saudi Arabia',
#                  '193': 'مش_عربية.',
#                  '194': 'Saudi Arabia',
#                  '197': 'جدة ..حقنا',
#                  '198': 'None',
#                  '2': 'وطني الغالي',
#                  '200': 'Jeddah, Saudi Arabia',
#                  '201': 'Saudi Arabia',
#                  '202': 'Saudi Arabia',
#                  '203': 'None',
#                  '204': 'Saudi Arabia',
#                  '205': ', المملكة العربية السعودية',
#                  '206': 'None',
#                  '208': 'None',
#                  '209': 'مكة المكرمة, المملكة العربية ا',
#                  '210': 'None',
#                  '211': 'Saudi Arabia',
#                  '212': 'حيـث أگون',
#                  '213': 'None',
#                  '214': 'Saudi Arabia',
#                  '216': 'None',
#                  '217': 'Saudi Arabia',
#                  '218': 'Saudi Arabia',
#                  '219': 'None',
#                  '221': 'None',
#                  '223': 'None',
#                  '225': 'Al ain/ AbuDhabi',
#                  '226': 'Saudi Arabia',
#                  '228': 'Saudi Arabia',
#                  '233': 'United States',
#                  '234': 'Saudi Arabia',
#                  '235': 'None',
#                  '236': 'None',
#                  '237': 'حيث أكون',
#                  '238': 'None',
#                  '239': 'Saudi Arabia',
#                  '24': 'None',
#                  '240': 'Kuwait',
#                  '241': 'Kuwait',
#                  '242': 'None',
#                  '243': '\u200fMadrid, Santiago Bernabéu',
#                  '244': 'Saudi Arabia',
#                  '245': 'Saudi Arabia',
#                  '246': 'Saudi Arabia',
#                  '247': 'Saudi Arabia',
#                  '248': 'في سوفي الدمام',
#                  '25': 'khobar ksa - akkar lebanon',
#                  '253': 'k.S.A / makkah',
#                  '255': 'Saudi Arabia',
#                  '256': 'None',
#                  '257': 'Saudi Arabia',
#                  '258': 'Saudi Arabia',
#                  '259': 'None',
#                  '26': 'None',
#                  '261': 'Saudi Arabia',
#                  '263': 'None',
#                  '264': 'Saudi Arabia',
#                  '270': 'مسقط, سلطنة عمان',
#                  '272': 'Saudi Arabia',
#                  '275': 'بريدة - طريق عمر بن الخطاب',
#                  '277': 'تبوك, المملكة العربية السعودية',
#                  '281': 'None',
#                  '284': 'None',
#                  '285': 'None',
#                  '286': 'أسكُن حيثُ تسكن البلابل',
#                  '288': 'كفر الشيخ, مصر',
#                  '29': 'مومباي/ الهند',
#                  '290': 'None',
#                  '293': 'Saudi Arabia',
#                  '294': 'مومباي . الهند',
#                  '297': 'None',
#                  '298': 'None',
#                  '3': 'Saudi Arabia',
#                  '307': 'None',
#                  '309': 'الامارات العربية المتحدة',
#                  '31': 'None',
#                  '310': 'مكة المكرمة, السعودية🇸🇦',
#                  '311': 'None',
#                  '313': 'مكة المكرمة, السعودية🇸🇦',
#                  '315': 'None',
#                  '319': 'None',
#                  '32': 'في قلبها ... في قلبه',
#                  '321': 'kuwait ️',
#                  '323': 'None',
#                  '325': 'أينما يكون السلام .. أكون !',
#                  '326': 'Saudi Arabia',
#                  '328': 'دار ممر',
#                  '330': 'موزمبيق',
#                  '331': 'None',
#                  '332': 'None',
#                  '333': 'لندن',
#                  '334': 'Saudi Arabia',
#                  '335': 'Saudi Arabia',
#                  '336': 'None',
#                  '337': 'Saudi Arabia',
#                  '338': 'فروعنا بمكه وجده والطايف',
#                  '339': 'None',
#                  '340': 'Kuwait',
#                  '341': 'None',
#                  '342': 'United Arab Emirates',
#                  '344': 'egypt / cairo',
#                  '350': 'None',
#                  '351': 'Saudi Arabia',
#                  '361': 'None',
#                  '363': 'None',
#                  '368': 'None',
#                  '369': 'None',
#                  '37': 'Saudi Arabia',
#                  '376': 'None',
#                  '377': 'Taif, Kingdom of Saudi Arabia',
#                  '378': 'Saudi Arabia',
#                  '379': 'مومباي الهند',
#                  '38': '',
#                  '381': 'Saudi Arabia',
#                  '382': 'None',
#                  '383': 'حائل, المملكة العربية السعودية',
#                  '385': 'None',
#                  '386': 'None',
#                  '387': 'Kuwait',
#                  '388': 'None',
#                  '389': 'None',
#                  '39': 'ليبيا',
#                  '41': 'None',
#                  '42': 'Saudi Arabia',
#                  '43': 'Saudi Arabia',
#                  '44': 'None',
#                  '47': 'None',
#                  '48': 'جــــــــــــدة',
#                  '51': 'Saudi Arabia',
#                  '52': 'Saudi Arabia',
#                  '54': 'None',
#                  '55': 'Riyadh | للإعلان التواصل خاص',
#                  '56': 'Riyadh | للإعلان التواصل خاص',
#                  '57': 'None',
#                  '58': 'Riyadh | للإعلان التواصل خاص',
#                  '59': 'Riyadh | للإعلان التواصل خاص',
#                  '6': 'None',
#                  '60': 'None',
#                  '63': 'None',
#                  '69': 'None',
#                  '7': 'Saudi Arabia',
#                  '72': 'None',
#                  '74': 'None',
#                  '75': 'None',
#                  '78': 'مومباي . الهند',
#                  '8': 'None',
#                  '80': 'None',
#                  '81': 'سكاكا, المملكة العربية السعودية',
#                  '84': 'None',
#                  '85': 'Saudi Arabia',
#                  '86': 'None',
#                  '87': 'Saudi Arabia',
#                  '88': 'Saudi Arabia',
#                  '89': 'Saudi Arabia',
#                  '9': 'None',
#                  '90': 'None',
#                  '91': 'None',
#                  '93': 'BAHA, Kingdom of Saudia Arabia',
#                  '96': 'abn-Alkuwait',
#                  '97': 'Kuwait - الكويت',
#                  '99': 'Saudi , Riyadh'},
#  'cleaned_name': {'0': 'UNaj0w',
#                   '1': 'CupsOfKarak',
#                   '10': 'AfnanMuq',
#                   '100': 'awada2861',
#                   '111': 'audi_nnn',
#                   '114': 'sajjaa_asensio',
#                   '115': 'ragksa2',
#                   '116': 'sq_zool',
#                   '119': 'shbr11',
#                   '12': 'fah_ad8',
#                   '120': 'shbr11',
#                   '121': 'Abdli555',
#                   '125': 'shbr11',
#                   '126': 'Moood',
#                   '128': 'MANS_HAZ',
#                   '13': 'mouse_Q8',
#                   '131': 'farhan99185',
#                   '133': 'ExJ8s',
#                   '134': 'shataaaaat',
#                   '135': 'kagool505',
#                   '14': '_Riyadh',
#                   '142': 'Shhhh501',
#                   '143': 'Ask_Almadina',
# ...
#                         'مثلاً...',
#                   '253': 'انا من زمان مغسلة يدي من الزواج ودحين اقتنعت اكتر',
#                   '255': 'اي مخرب لو بس يحال للمحكمة تلقاه بيموت من الفجعة .. '
#                          'لابد من قانون صارم وعقوبة مغلظة ولابد من شرطة جوال…',
#                   '256': 'انا ساكنه في فانكوفر في النورث وأخذنا سياره مستخدمه '
#                          'اذ تعرف مغسلة سيارة تغسلها من جواء والكنب كلها الله '
#                          'يجزاك خير',
#                   '257': 'صاروخ ولا مغسلة ذا',
#                   '258': 'أعتقد والله أعلم أن أول جامعة سعودية غلست شهادة هي '
#                          'جامعة الملك سعود وان أكبر مغسلة للشهادات الآن هي '
#                          'جامعة المجمعة',
#                   '259': ': أعتقد والله أعلم أن أول جامعة سعودية غلست شهادة هي '
#                          'جامعة الملك سعود وان أكبر مغسلة للشهادات الآن هي '
#                          'جامعة المجمعة',
#                   '26': 'في بعض الأحيان عندما يكون العمل في مشروعي الخاص '
#                         'متعباً وبدون عائد مالي، تقترح علي والدتي بأن أترك كل '
#                         'شيء وأن أفتح م…',
#                   '261': 'أعتقد ان أول جامعة "غسلت" شهادة من نوع هي جامعة '
#                          'الملك سعود وان أكبر مغسلة للشهادات الآن هي جامعة '
#                          'المجمعة',
#                   '263': ': أعتقد ان أول جامعة "غسلت" شهادة من نوع هي جامعة '
#                          'الملك سعود وان أكبر مغسلة للشهادات الآن هي جامعة '
#                          'المجمعة …',
#                   '264': 'اعتقد ان أول جامعة سعودية غسلت شهادة دكتوراه من نوع '
#                          'هي جامعة الملك سعود وان أكبر مغسلة للشهادات الآن هي '
#                          'جام…',
#                   '270': 'خل عنك الجو طارق و تعال شلني من عند مغسلة المحطه',
#                   '272': ': ياشباب السلام عليكم ورحمة الله وبركاته فتحت مغسلة '
#                          'سيارات وفيه تخفيض خمسين في الميه للمتابعين الي عندي '
#                          'غسيل من داخل…',
#                   '275': 'شد فوق مستوى التندةمع ناموسية وجلسات جانبية ،، مغسلة '
#                          '،،ماطور هواء ومضخة ماء(عروق الشمال)',
#                   '277': ': شد فوق مستوى التندةمع ناموسية وجلسات جانبية ،، '
#                          'مغسلة ،،ماطور هواء ومضخة ماء(عروق الشمال)',
#                   '281': '_ضمان١٠سنوات /خلاط دش تيرا /خلاط دوش روزا ضمان سنوات '
#                          '/ خلاط مغسلة جينا / خلاط دش دينا ضمان س…',
#                   '284': ': _ضمان١٠سنوات /خلاط دش تيرا /خلاط دوش روزا ضمان '
#                          'سنوات / خلاط مغسلة جينا / خلاط دش دينا ضمان س…',
#                   '285': ': مغسلة + كرسي من اليوبي ب ريال فقط بدلاً من ريال '
#                          'العرض لفترة محدودة *تطبق الشروط والاحكام* "اليوبي '
#                          'يوفر ما…',
#                   '286': 'بعض الإخوانيين وجوههم مغسلة بمرق.. والله ما يستحوا.. '
#                          'ينشروا أخبار كاذبة حقد ما بعده حقد.. افضحوهم بارك '
#                          'الله سعيكم..',
#                   '288': 'مروحة شفط تشوف البخار يطلع من اذانيك تقل مغسلة بخار',
#                   '29': 'السلام عليكم عندنا عمالين جاهز عامل نظافة عامل معماري '
#                         'عامل تربية مواشي عامل مغسلة عامل الجبس عامل استراحة',
#                   '290': 'اكيد ان صاحب هذه الدراسة يملك مغسلة عادي ومستعجل',
#                   '293': '•ضمان سنتين شطاف كاديا شطاف داليا •ضمان سنوات شاور '
#                          'مع مسطرةصاعد نازل كروم شاور مع مسطرة(صاعد ن…',
#                   '294': ': مرحبا عندنا عمالين جاهز سواق خاص عامل منزلي عامل '
#                          'استراحة كوفي شوب معلم بوفية عامل مغسلة خياط ملابس '
#                          'رجالية كهرباء و…',
#                   '297': 'ما هي قصة الغسل هذه؟:',
#                   '298': 'عادة قديمه زمان الكل كان يسويها .. والان المطاعم '
#                          'يسونها وايضا مغسلة الملابس يغسلون ملابس المريض '
#                          'والنظيف والوسخ مع بعض',
#                   '3': 'مخطط من بعد مغسلة الضاحي',
#                   '307': 'مرافق محطة النرجس:للايجار مغسلة بنشر زيت بقالة بنزين '
#                          'ورشة قيمة الاجار الف في السنه',
#                   '309': 'للبيع. بعجمان. مغسلة سيارات فيها رخصة تنجيد مقاعد '
#                          'السيارات وتركيب زينه السيارات والاكسسوارات…',
#                   '31': 'بعض الأنشطة متروك تسعيرها بحجة أنها يدوية كمغاسل '
#                         'السيارات مثلاً كل مغسلة لها سعر لماذا لا تصنف ويصبح '
#                         'لها تسعيرة موحدة',
#                   '310': 'ترتيب المطبخ وشيل البوتغار من جنب مغسلة المواعين '
#                          'طلعت سبب في المشاكل بين نبع الحنان وزو…',
#                   '311': '•ضمان سنتين /شطاف كاديا /شطاف داليا •ضمان سنوات '
#                          '/شاور مع مسطرة(صاعد نازل) كروم /شاور مع مسطر…',
#                   '313': 'شيل البوتاغاز من جنب مغسلة المواعين عشان نبع الحنان '
#                          'تخف مشاكلها',
#                   '315': 'ابراهيم قول لغازي نبغى مغسلة الغوازي',
#                   '319': 'النقاش معك عقيم نادي له جمهوره و تقولي مغسلة اتمنى '
#                          'ترتقي بالنقاش',
#                   '32': ': اعجبتني فكرة محل المغسلة اللي يجون ياخذون منك '
#                         'الملابس اللي ماتبغاها كل اثنين ويغسلونها ويطلعونها '
#                         'صدقة ، بس للاسف ان…',
#                   '321': 'عاد بكيفكم غيرو مكان الچولة خلوه بالحوش بالصاله '
#                          'بغرفه النوم اهم شيي مايكون عند مغسلة المواعين ودي '
#                          'اصدق المعلومه هذ…',
#                   '323': ': شيل البوتاغاز من جنب مغسلة المواعين عشان نبع '
#                          'الحنان تخف مشاكلها',
#                   '325': ': لا تسجل حساب في البقالة ولا محطة البنزين ولا مغسلة '
#                          'الملابس ولا أي مكان خدمي .. تعود تصرف كاش أو…',
#                   '326': 'العوالي شارع ابراهيم الجفالي قبل اول اشاره بالشارع '
#                          'تشوفه على يمينك جنب مغسلة سيارات',
#                   '328': ': السلام عليكم ورحمة الله وبركاته فتحت مغسلة سيارات '
#                          'وفيه تخفيض خمسين في الميه ل اللي يعز عليك غسيل من '
#                          'داخل وخارج ا…',
#                   '330': ': مغسلة من أعمالنا مع موديلات مختلفة من أحواضنا '
#                          'الرخامية للطلبات تواصلوا معنا على واتساب:',
#                   '331': 'انا املك مغسلة سيارات معطيني عامل فيزا خارجيه '
#                          'والباقي داخلي !!! ماخليت احد ماكلمته ابي يزيدون عدد '
#                          'ا…',
#                   '332': '؛ رسالة وصلتنا : غطاء هاتف. مكسور فـ منتصف الشارع '
#                          'بجوار مغسلة جود للملابس. مقابل إدارة المياه :…',
#                   '333': 'احمد ربك حصلت اربعه',
#                   '334': 'مغسلة الجوري',
#                   '335': 'مغسلة ديكور انطلاق اكبر مهرجان للخصومات من زينكو خصم '
#                          'يبدأ من % حتى % …',
#                   '336': ': مغسلة ديكور انطلاق اكبر مهرجان للخصومات من زينكو '
#                          'خصم يبدأ من % حتى % …',
#                   '337': 'من الخاص السلام عليكم ايش افضل مغسلة البطانيات في '
#                          'وشكرا',
#                   '338': 'مغسلة ديكور مزدوجه انيقه جدامن dreamsste **اكبر حملة '
#                          'تخفيضات على جميع…',
#                   '339': ': ؛ رسالة وصلتنا : غطاء هاتف. مكسور فـ منتصف الشارع '
#                          'بجوار مغسلة جود للملابس. مقابل إدارة المياه :…',
#                   '340': 'عرض خاص لأعضاء جمعية المهندسين الكويتية من مغسلة ذا '
#                          'ديزرت المركزية الأسعار المعلنة خاصة لأعضاء…',
#                   '341': 'من رسائلكم مطلوب محل للايجار يصلح ل مغسلة سيارات ضمن '
#                          'الميزتلي',
#                   '342': ': لو اني فتحت مغسلة في الصناعية كان اشرفلي من دخلتي '
#                          'على هل جامعة',
#                   '344': 'متاح عدة مغسلة كاملة للبيع لو حد عايز يكلمني العدة '
#                          'عبارة عن : كاتشر إيطالي حصان بار بالخرطوم و '
#                          'المسدس...',
#                   '350': ': اعتقد ان أول جامعة سعودية غسلت شهادة دكتوراه من '
#                          'نوع هي جامعة الملك سعود وان أكبر مغسلة للشهادات الآن '
#                          'هي جام…',
#                   '351': ': لاأزال لا أستوعب سبب عدم منح تراخيص لجمعيات '
#                          'تعاونية تنتشر في الاحياء و يصمًم لها نموذج موحًد '
#                          'كما…',
#                   '361': 'ضمان سنتين شطاف كاديا شطاف داليا ضمان سنوات شاور مع '
#                          'مسطرة(صاعد…',
#                   '363': 'ضمان سنتين شطاف كاديا شطاف داليا ضمان سنوات شاور مع '
#                          'مسطرة(صاعد نازل) كروم شاور مع مسطرة(صاعد…',
#                   '368': 'ضمان سنتين شطاف كاديا شطاف داليا ضمان سنوات شاور مع '
#                          'مسطرة(صاعد نا…',
#                   '369': 'ضمان سنتين شطاف كاديا شطاف داليا ضمان سنوات شاور مع '
#                          'مسطرة(صاعد نازل) كروم شاور مع مسطرة(صاعد نا…',
#                   '37': 'مغسلة السيارات المتنقلة تلميع او غسيل السيارة نخدمك '
#                         'وانت في بيتك ودوامك و استراحتك للتواصل …',
#                   '376': 'ضمان سنتين شطاف كاديا شطاف داليا ضمان سنوات شاور مع '
#                          'مسطرة(صاعد نازل)…',
#                   '377': ': لكم أن تتخيلوا قساوة المشهد وألم الشعور عندما قبلت '
#                          'أمي على جبينها قبلة الوداع وهي في مغسلة الاموات ، '
#                          'اللهم ارحم أمي.',
#                   '378': ': فكرة انارة مغسلة مع انارة مركزة على الورد',
#                   '379': 'مرحبا مكتب استقدام الهند يوجد لدي: عامل مزارع عامل '
#                          'عادي عامل استراحة عامل مغسلة عامل نظافة عامل مطعم '
#                          'عامل شاورما الواتساب',
#                   '38': 'اهلا وسهلا مرحبا مكتب استقدام العمالة الهند عندنا '
#                         'موجود عمال كل نفر قديم و جديد سواقين عامل استراحة '
#                         'عامل مغسلة ع…',
#                   '381': ': ضمان سنتين شطاف كاديا شطاف داليا ضمان سنوات شاور '
#                          'مع مسطرة(صاعد نازل) كروم شاور مع مسطرة(صاعد…',
#                   '382': ': اسرع طريقة صاروخيه لكسب الاموال من عامل فى مغسلة '
#                          'سيارات الى مطوع يرش مويه مقري',
#                   '383': '…',
#                   '385': 'بغزل حمامي كلهم سيفون الا انت مغسلة',
#                   '386': 'حاشا هذي ماهي امراه هاذي مغسلة سيارات',
#                   '387': ': عرض خاص لأعضاء جمعية المهندسين الكويتية من مغسلة '
#                          'ذا ديزرت المركزية الأسعار المعلنة خاصة لأعضاء…',
#                   '388': 'والله ما أحد مستانس غير طلاب الابتدائي متسدحين '
#                          'بايباداتهم وشهاداتهم كلها واحد واحد واحد تقول فاتورة '
#                          'مغسلة',
#                   '389': 'ماشاء الله ... ياليث يعمم في الطرق السريعة مثل هذه '
#                          'الخدمات ويحافظ عليها ويتم مراقبتها ... أنا لست '
#                          'مهندسة لكن احدى…',
#                   '39': 'اول مغسلة',
#                   '41': ': مغسلة رخامية كاملة',
#                   '42': ': مغسلة السيارات المتنقلة تلميع او غسيل السيارة نخدمك '
#                         'وانت في بيتك ودوامك و استراحتك للتواصل …',
#                   '43': ': أين أجد مغسلة تقوم بغسل مراتب الاسرة',
#                   '44': 'مغسلة الجبر',
#                   '47': 'تكنت: اعتقال متهم بسرقة مغسلة بانواكشوط',
#                   '48': 'مـﻧـــ الخاصــــ ابغى مغسلة تغسل بستم بخار؟',
#                   '51': ': مغسلة صينى حوضين خشب معالج ( PVC ) موديل مقاس سم '
#                         'ثلاثة الوان البنى والابيض والبيج مع احواض سيراميك '
#                         'وسطح رخ…',
#                   '52': 'نعدي على لنّو ونمشي ( مغسلة المستقبل)',
#                   '54': ': من المساواة الزوجية مثل ما زوجتك تاخذك معها مجمعات '
#                         'اسواق مطاعم سفرات محلات عطور محلات ثياب محلات مكياج '
#                         'انت…',
#                   '55': 'من الخاص : هل فيه محل يبيع معدات مغسلة ملابس وكم '
#                         'اسعارها اذ في احد اشترا معدات مستخدمه يفيدناا ، شكرا.',
#                   '56': 'من الخاص : السلام عليكم ابي افضل مغسلة سيارات في شرق '
#                         'الرياض مخرج وشكراً.',
#                   '57': ': اهم شي مغسلة الغوازي',
#                   '58': ': من الخاص : هل فيه محل يبيع معدات مغسلة ملابس وكم '
#                         'اسعارها اذ في احد اشترا معدات مستخدمه يفيدناا ، شكرا.',
#                   '59': ': من الخاص : السلام عليكم ابي افضل مغسلة سيارات في '
#                         'شرق الرياض مخرج وشكراً.',
#                   '6': 'مغسلة طيبه الاوتوماتيكيه اسعارهم حلوه',
#                   '60': ': مشروع مغسلة سيارات متنقلة الفكرة مربحةحيث أنك تقدم '
#                         'خدمة وليست منتج وبالتالي أغلب مايصلك من إيرادات يعتبر '
#                         'أرباح',
#                   '63': 'أعادة ضبط المصنع مع القليل من البهارات الزيدية.. لم '
#                         'يجد مغسلة مع حركة بسيطة يغير ولاءه.. ⤵خبث زيدي '
#                         'بأمتياز',
#                   '69': 'من الأفكار جمع معاليق الملابس وردها لصاحب مغسلة '
#                         'الملابس ليستفيد منها أفكار_خيرية',
#                   '7': 'مغسلة مركبة بمسمارين و شوية سيلكون مصيرها السقوط اذا '
#                        'مو اليوم بكره... لاتلوم الناس بس لوم الشركة المنفذة '
#                        'ايضا',
#                   '72': 'السلام عليكم مشغل ابيض واسود على طريق الملك خالد '
#                         'يستحوذ ويستولي على كامل طريق المشاة تعديات في شارع…',
#                   '74': ': مغسلة سجاد الحرم المكي الشريف',
#                   '75': 'نمت وأنا مغسلة يدي من اليوم وأنا ما نمت تمام ، بس '
#                         'صحيت بدري كان مش مروقة أبداً ، لكن قاومت بالمره أقدر '
#                         'أقول إني دحين فايقة ورايقة .',
#                   '78': 'مرحبا عندنا عمالين جاهز سواق خاص عامل منزلي عامل '
#                         'استراحة كوفي شوب معلم بوفية عامل مغسلة خياط ملابس '
#                         'رجالية كهرباء و…',
#                   '8': 'سألت واحد في اليمن ايش احسن مشروع استثماري في اليمن..؟ '
#                        'قال :احسن…',
#                   '80': ': مغسلة ديكور نطلاق اكبر مهرجان للخصومات من زينكو خصم '
#                         'يبدأ من % حتى % …',
#                   '81': ': السلام عليكم مشغل ابيض واسود على طريق الملك خالد '
#                         'يستحوذ ويستولي على كامل طريق المشاة تعديات في شارع…',
#                   '84': 'كرسي + مغسلة موديل اورينت ، متوفر بأكثر من لون بسعر '
#                         'ريال. بيديه موديل اورينت ، متوفر بأكثر من لون بسعر '
#                         'ريال…',
#                   '85': 'كرسي + مغسلة موديل فلورا ، متوفر بأكثر من لون ب ريال '
#                         'فقط بيدية موديل فلورا متوفر بأكثر من لون ب ريال فقط '
#                         'مر…',
#                   '86': 'كرسي + مغسلة موديل اورينت مرخم ، متوفر بأكثر من لون '
#                         'بسعر ريال. بيديه موديل اورينت مرخم ، متوفر بأكثر من '
#                         'لون بسع…',
#                   '87': 'كرسي + مغسلة موديل فلورا مرخم بأكثر من لون ب ريال فقط '
#                         'بيدية موديل فلورا مرخم بأكثر من لون ب ريال فقط مرر '
#                         'الص…',
#                   '88': 'كرسي + مغسلة موديل فلورا ، متوفر بأكثر من لون ب ريال '
#                         'فقط كرسي + مغسلة موديل فلورا مرخم بأكثر من لون ب '
#                         'ريال…',
#                   '89': 'كرسي + مغسلة موديل اورينت ، متوفر بأكثر من لون ب ريال '
#                         'فقط كرسي + مغسلة موديل اورينت مرخم بأكثر من لون ب '
#                         'ريا…',
#                   '9': 'فيه مغسلة في مخطط الملك فهد، جنب محطة الوصابي ( اكثر '
#                        'من واحد مدحها ) ماني متأكد من اسمها ( احتمال طيبة 🤔 )',
#                   '90': 'بحمد الله تم الأنتهاء من مغسلة السيارات المتنقله '
#                         'دعمكم مهم .......',
#                   '91': 'لاتهتم عندنا مغسلة قطارات',
#                   '93': 'المنشفه اللي انشف فيها وجهي قمت الصباح لقيتهم ممسحين '
#                         'فيها مغسلة المطبخ',
#                   '96': 'مغسلة يد متنقلة على التنكر 🤔',
#                   '97': 'فيديو | فتاتان تديران مغسلة للسيارات',
#                   '99': 'المتستر اللي ما يدري عماله كم يبيعون يبي له ينتبه . '
#                         'حلاق .. مغسلة .. بقالة الخ . الان ممكن يوقفون خدماته'}}

# %% [markdown]
# #### Create a reference to `my_gulf_collection`

# %%
coll_ref_gulf = tweets_db.my_gulf_collection

# %%
coll_ref_gulf.count()
# Out:
# 422

# %%
cursor_gulf = coll_ref_gulf.find()

cursor_gulf

gulf_sample_docs = list(cursor_gulf)

# %%
gulf_tweets = list(coll_ref_gulf.find())

# %%
gulf_sample_docs[:5]
# Out:
# [{'_id': ObjectId('5a26e4674be1040215461f14'),
#   'cleaned_geo': 'United Arab Emirates',
#   'cleaned_name': 'typicallynorah',
#   'cleaned_text': ': على الاقل ارحم من ان تتعود على وجود احد ويغرقك اهتمام وحب ويغنيك عن الدنيا وبنص الطريج يخليك تعاني وتت…'},
#  {'_id': ObjectId('5a26e4674be1040215461f15'),
#   'cleaned_geo': 'Dokhaa',
#   'cleaned_name': 'Hasan95780025',
#   'cleaned_text': 'وحدة مكافحة الموز في الطريج'},
#  {'_id': ObjectId('5a26e4674be1040215461f16'),
#   'cleaned_geo': 'None',
#   'cleaned_name': 'FathiyaAjlan1',
#   'cleaned_text': 'انا صوت الفريج وبنتٍ تناديك تدليك الفرح وينه انا ثوبك وسبحةٍ في يدك واللي راح من عمرك انا اشيله أدليك الطريج اللي…'},
#  {'_id': ObjectId('5a26e4674be1040215461f17'),
#   'cleaned_geo': 'None',
#   'cleaned_name': 'hodaaa_q8',
#   'cleaned_text': 'اوك مسافة الطريج يايتلچ \u200d️\u200d️\u200d️'},
#  {'_id': ObjectId('5a26e4674be1040215461f18'),
#   'cleaned_geo': 'Kuwait',
#   'cleaned_name': 'DzY9d',
#   'cleaned_text': 'كلام جميل لكن وين التطبيق.طلع قانون للخدم ونشر بالجريدة الرسمية من زمان وللحين احنا ناطرين ا…'}]

# %%
gulf_tweets_df = pd.DataFrame(gulf_sample_docs)

# %%
gulf_tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 4 columns):
# _id             422 non-null object
# cleaned_geo     422 non-null object
# cleaned_name    422 non-null object
# cleaned_text    422 non-null object
# dtypes: object(4)
# memory usage: 13.3+ KB

# %%
gulf_tweets_df['class'] = 'GULF'

# %%
gulf_tweets_df.head()
# Out:
#                         _id           cleaned_geo    cleaned_name  \
# 0  5a26e4674be1040215461f14  United Arab Emirates  typicallynorah
# 1  5a26e4674be1040215461f15                Dokhaa   Hasan95780025
# 2  5a26e4674be1040215461f16                  None   FathiyaAjlan1
# 3  5a26e4674be1040215461f17                  None       hodaaa_q8
# 4  5a26e4674be1040215461f18                Kuwait           DzY9d
#
#                                         cleaned_text class
# 0  : على الاقل ارحم من ان تتعود على وجود احد ويغر...  GULF
# 1                        وحدة مكافحة الموز في الطريج  GULF
# 2  انا صوت الفريج وبنتٍ تناديك تدليك الفرح وينه ا...  GULF
# 3                     اوك مسافة الطريج يايتلچ ‍️‍️‍️  GULF
# 4  كلام جميل لكن وين التطبيق.طلع قانون للخدم ونشر...  GULF

# %%
combined_df_streamed_timelines = eg_tweets_df.append([gulf_tweets_df])

# %%
combined_df_streamed_timelines.to_pickle('../CAPSTONE/Pickled_from_mongo/combined_eg_gulf.p')
