# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# #### Import pickled stop words from `Effects of Stop Words Elimination for Arabic Information Retrieval: A Comparative Study`

# %%
stop_words_df = pd.read_pickle('/home/jovyan/capstone-52/topic_modeling_experiments/pickled_stopwords/comp_study_stopwords.p')

# %%
stop_words_df.columns = ["stop_words"]

# %%
stop_words_df.columns
# Out:
# Index(['stop_words'], dtype='object')

# %%
dfList_stopwords = stop_words_df['stop_words'].tolist()

# %%
dfList_stopwords[:4]
# Out:
# ['انها', 'اثناء', 'اجل', 'احدا']

# %%
pd.set_option('display.max_colwidth', -1)

# %%
cd Pickled_from_mongo/
# Out:
# /home/jovyan/capstone-52/Pickled_from_mongo

# %%
df = pd.read_pickle('../Pickled_from_mongo/combined_eg_gulf.p')

# %%
df = df.drop(['_id', ], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 940 entries, 0 to 421
# Data columns (total 4 columns):
# cleaned_geo     940 non-null object
# cleaned_name    940 non-null object
# cleaned_text    940 non-null object
# class           940 non-null object
# dtypes: object(4)
# memory usage: 36.7+ KB

# %% [markdown]
# ## Benchmark LSA with stop words

# %% [markdown]
# ### Label Encode the Categories

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df['class_numerical'] = le.fit_transform(df['class'])

# %% [markdown]
# ### Prepare Document Term Matrix

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(min_df = 1, stop_words= dfList_stopwords)

# %% [markdown]
# ### TFIDF

# %%
document_term_matrix_sps = tfidf_vectorizer.fit_transform(df.cleaned_text)

# %%
document_term_matrix_sps
# Out:
# <940x4078 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8248 stored elements in Compressed Sparse Row format>

# %%
document_term_matrix_df = pd.DataFrame(document_term_matrix_sps.toarray(),
                                       index=df.index,
                                       columns=tfidf_vectorizer.get_feature_names())

# %% [markdown]
# ### Compute SVD of Document Term Matrix

# %%
from sklearn.decomposition import TruncatedSVD

# %%
n_components = 2
SVD = TruncatedSVD(n_components)
component_names = ["component_"+str(i+1) for i in range(n_components)]

# %%
svd_matrix = SVD.fit_transform(document_term_matrix_df)

# %%
SVD.explained_variance_ratio_
# Out:
# array([ 0.01476262,  0.01254277])

# %%
svd_matrix[:4]
# Out:
# array([[ 0.00562777,  0.00031397],
#        [ 0.0032347 ,  0.00039073],
#        [ 0.00199008,  0.0001426 ],
#        [ 0.00560469,  0.00042567]])

# %% [markdown]
# ### Load SVD Matrix with Documents and Labels

# %%
latent_semantic_analysis = pd.DataFrame(svd_matrix,
                                        index=document_term_matrix_df.index,
                                        columns=component_names)
latent_semantic_analysis['cleaned_text'] = df.cleaned_text
latent_semantic_analysis['class'] = df['class']

# %%
latent_semantic_analysis.sample(10)
# Out:
#      component_1  component_2  \
# 356  0.132370    -0.000011
# 322  0.001395     0.001938
# 104  0.157582    -0.000187
# 293  0.189601    -0.000032
# 161  0.178516    -0.000245
# 353  0.335094    -0.000175
# 158  0.007747    -0.000262
# 15   0.004672    -0.000043
# 129  0.165449     0.000012
# 164  0.091085     0.000025
#
#                                                                                                                cleaned_text  \
# 356  اهلا اهلا اهلا ازيك وازي مصر ، وحشتنا ياراجل
# 322  بسالك الحوطه فيها مغسلة ملابس بخار ووين موقعها
# 104  وبناقص من كلمة ازيك لو بتقولوها عشان تبقوا عملتوا اللي عليكم...
# 293  بسأل على نفسي ف بقولك ازيك
# 161  ازيك ياكابتن محمد المنوفية بتحيك
# 353  ازيك يا محمود
# 158  : اسمعني عاد اقول لك يا .. . انت الذي اخترت الطريج وأشعلت في يوفي حريج أتركني في حالي وارحل على خير لا…
# 15   : أزاي كل مرة بنشوفكم فيها، بنحس كأنها أول مرة، بنحس بنفس اللهفة، نفس النظرة، نفس النفس الطويل اللي بناخده، و نفس حال…
# 129  م الفل فؤش ازيك يا شقيق منور 🤣
# 164  ازيك ياعمرو باشا انا ضياء البنا محاسب مقيم في السعوديه ومن مركز قويسنا المنوفيه العمر سنه الحال اليج…
#
#     class
# 356  EG
# 322  GULF
# 104  EG
# 293  EG
# 161  EG
# 353  EG
# 158  GULF
# 15   EG
# 129  EG
# 164  EG

# %%
vocabulary_loadings = pd.DataFrame(SVD.components_,
                                   index=component_names,
                                   columns=tfidf_vectorizer.get_feature_names()).T

# %%
vocabulary_loadings['abs_component_1'] = np.abs(vocabulary_loadings.component_1)
vocabulary_loadings['abs_component_2'] = np.abs(vocabulary_loadings.component_2)

# %% [markdown]
# ### Display Top Terms for Each Component

# %%
vocabulary_loadings.sort_values('abs_component_1',ascending=False).head(10)
# Out:
#           component_1  component_2  abs_component_1  abs_component_2
# ازيك      0.942229    -0.000023     0.942229         0.000023
# ايه       0.074302    -0.001462     0.074302         0.001462
# rice      0.061969     0.000026     0.061969         0.000026
# مش        0.061268    -0.000256     0.061268         0.000256
# الحمدلله  0.057238     0.000069     0.057238         0.000069
# شوية      0.056888     0.000036     0.056888         0.000036
# تمام      0.055682     0.000912     0.055682         0.000912
# رز        0.055227     0.000002     0.055227         0.000002
# مديرهم    0.052970     0.000012     0.052970         0.000012
# الحمد     0.052233     0.003122     0.052233         0.003122

# %%
vocabulary_loadings.sort_values('abs_component_2',ascending=False).head(10)
# Out:
#        component_1  component_2  abs_component_1  abs_component_2
# شطاف   0.000010     0.461856     0.000010         0.461856
# ضمان   0.000040     0.408441     0.000040         0.408441
# شاور   0.000008     0.398471     0.000008         0.398471
# مسطرة  0.000007     0.345447     0.000007         0.345447
# صاعد   0.000006     0.309841     0.000006         0.309841
# كاديا  0.000005     0.230928     0.000005         0.230928
# سنتين  0.000005     0.230928     0.000005         0.230928
# داليا  0.000005     0.230928     0.000005         0.230928
# نازل   0.000004     0.223730     0.000004         0.223730
# كروم   0.000003     0.175301     0.000003         0.175301

# %%
plt.figure(figsize=(7,7))
pc_1 = latent_semantic_analysis['component_1'].values
pc_2 = latent_semantic_analysis['component_2'].values

plt.scatter(pc_1, pc_2, c=df['class_numerical'], cmap='rainbow')

plt.xlabel('First PC')
plt.ylabel('Second PC')
plt.axvline(linewidth=0.5)
plt.axhline(linewidth=0.5)
plt.xlim(-.1,1)
plt.ylim(-.5,1)
# Out:
# (-0.5, 1)

# %%
plt.figure(figsize=(6,6))
pc_1 = latent_semantic_analysis['component_1'].values
pc_2 = latent_semantic_analysis['component_2'].values

strings = df['cleaned_text'].values
for i, (x, y) in enumerate(zip(pc_1, pc_2)): 
    plt.text(x,y,strings[i][:10])

plt.scatter(pc_1, pc_2, c=df['class_numerical'], cmap='rainbow')

plt.xlabel('First PC')
plt.ylabel('Second PC')
plt.axvline(linewidth=0.5)
plt.axhline(linewidth=0.5)
plt.xlim(-.1,1)
plt.ylim(-.1,1)
# Out:
# (-0.1, 1)

# %%
plt.figure(figsize=(6,6))
pc_1 = latent_semantic_analysis['component_1'].values
pc_2 = latent_semantic_analysis['component_2'].values

plt.scatter(pc_1, pc_2, c=df['class_numerical'], cmap='rainbow')

plt.xlabel('First PC')
plt.ylabel('Second PC')
plt.axvline(linewidth=0.5)
plt.axhline(linewidth=0.5)
plt.xlim(-.01,.5)
plt.ylim(-.3,.6)
# Out:
# (-0.3, 0.6)

# %%
eg_mask = latent_semantic_analysis['class'] == 'EG'

# %%
latent_semantic_analysis[eg_mask]
# Out:
#      component_1  component_2  \
# 0    0.005628     0.000314
# 1    0.003235     0.000391
# 2    0.001990     0.000143
# 3    0.005605     0.000426
# 4    0.018170     0.000034
# 5    0.016596     0.000445
# 6    0.008033     0.000815
# 7    0.005158     0.000074
# 8    0.016765     0.000682
# 9    0.035273    -0.000121
# 10   0.009664    -0.000094
# 11   0.009589     0.000149
# 12   0.009589     0.000149
# 13   0.002719     0.000783
# 14   0.001026     0.000220
# 15   0.004672    -0.000043
# 16   0.027657    -0.000058
# 17   0.009664    -0.000094
# 18   0.012476     0.000483
# 19   0.000923     0.000533
# 20   0.020145    -0.000021
# 21   0.020145    -0.000021
# 22   0.007421     0.000237
# 23   0.024336     0.000198
# 24   0.024336     0.000198
# 25   0.002131     0.000512
# 26   0.001167     0.000268
# 27   0.014306    -0.000169
# 28   0.006665     0.000139
# 29   0.008166     0.000255
# ..        ...          ...
# 488  0.004027    -0.000389
# 489  0.004115    -0.000310
# 490  0.003623    -0.000115
# 491  0.009454     0.000294
# 492  0.014067    -0.000090
# 493  0.003294    -0.000243
# 494  0.004586    -0.000137
# 495  0.002441    -0.000219
# 496  0.003588    -0.000261
# 497  0.003248    -0.000095
# 498  0.005984    -0.000164
# 499  0.021876    -0.000292
# 500  0.000111     0.000141
# 501  0.005193    -0.000381
# 502  0.006587     0.000217
# 503  0.003442    -0.000026
# 504  0.017718     0.000056
# 505  0.014301     0.000111
# 506  0.002239    -0.000178
# 507  0.002239    -0.000178
# 508  0.012803     0.000094
# 509  0.005511    -0.000234
# 510  0.000111     0.000141
# 511  0.005476    -0.000236
# 512  0.007186    -0.000305
# 513  0.003730    -0.000013
# 514  0.003670    -0.000113
# 515  0.014018    -0.000209
# 516  0.003458    -0.000188
# 517  0.004210    -0.000322
#
#                                                                                                                            cleaned_text  \
# 0    أزاي أقول لك كنا زمان ... والماضي كان فى الغيب بكره واللي أحنا فيه دلوقت كمان ... ح يفوت علينا ولا ندري
# 1    هي آراء آه بس أزاي أجويرو منتهي يعني أمال لو مكنش الهداف التاريخي للسيتي و كل موسم اقل عدد من الاهداف…
# 2    أنت صيني أزاي تقارن شادي بالخطيب ألي هو الوحيد ألي خد الكورة الذهبية من مصر وبشهادت الزملكاوي قبل الأ…
# 3    أزاي الناس كانت بتغرد في الخمسينات قبل إختراع تويتر.
# 4    التوينز اللي معاها كل الحلو والوحش والمصايب والاكل والفشل مش عارفه من غيرك كنت هعيش أزاي ربنا يخليكي ليا ومش تويته توصفك
# 5    : عن الناس إلي ربنا بعتهالك عشان يقولك شوف آخر صبرك طلع حلو أزاي
# 6    شوفت لما تجاهلت الناس وشك نور أزاي
# 7    ده انا صاحيه من ساعه وزهقت هكمل أزاي بقيت اليوم من غير ما أنتحر
# 8    أزاي اتعرفت علي افضل صديق/ة عندك/ي؟ — افضل صديقة عندي مع بعض من اولى ابتدائي مش فاكرة اتعرفنا ازاي
# 9    اكيد مكنتيش هتقدري تعيشي ي بنتي ، انتي م غيري ولا اي حاجة أصلاً انا عارفهه ، وعارفه أن مش تويته توصفني ده اكي…
# 10   الله اكبر رووووووووعه
# 11   أول مرة أسمع أغنية رق الحـبيب لأم كلثـوم كـامله حقيقي الست دي كـانت أزاي كدا !
# 12   : أول مرة أسمع أغنية رق الحـبيب لأم كلثـوم كـامله حقيقي الست دي كـانت أزاي كدا !
# 13   أزاي يعني واحد يكون مجرم ويطلع براة
# 14   البعُد عنك خوف وأنا ع الرجوع ملهوف ، لكن أعود أزاي ومكاني كله ضيوف ...!
# 15   : أزاي كل مرة بنشوفكم فيها، بنحس كأنها أول مرة، بنحس بنفس اللهفة، نفس النظرة، نفس النفس الطويل اللي بناخده، و نفس حال…
# 16   : مش عارفة هصحي الساعه عشان احضر سكشن أزاي و الساعه دلوقتي !!
# 17   : الله اكبر رووووووووعه
# 18   : أنت غيرت المقام كدا أزاي الشيخ ماشاء الله
# 19   مستنين أيه !! شوفوا اليمن وليبيا أزاي عملوا بالقذافي وصالح واعملوا زيهم
# 20   لا يا عم ده حالق دقنه بس
# 21   : لا يا عم ده حالق دقنه بس
# 22   : اللي شُفته قبل مَا تشوفك عينيًّا عُمْر ضايع يحسبوه أزاي عليّا
# 23   لا دا عشان حلقت بس
# 24   : لا دا عشان حلقت بس
# 25   أزاي اتعرفت علي افضل صديق/ة عندك/ي؟ — جامعه
# 26   أزاي ابدأ في الشبكات | Network: via
# 27   جيل كامل من الأباء والأمهات ماعرفوش يربوا أولادهم أزاي يكون أنسان وان الشر از الظلم اللي انت اتعرضت له مش لازم ترده…
# 28   أزاي عندك حب اﻷمتﻻك ده !!
# 29   : اللي شوفته قبل ما تشوفك عنيّا.. عُمْر ضايع ، يحسبوه أزاي عليّا
# ..                                                                ...
# 488  لو قدامي كوباية شاي بلبن ب خمسين جنية هجيبها
# 489  هعمل كوباية شاي واتفرج عليك
# 490  تعال اعملك احلي كوباية
# 491  بعد سنة رجعت انتقم منك هتدوق من نفس الكاس اللي انا شربت منه =بس أنا بقرف _ثواني اجيب كوباية تانية
# 492  ميبقاش ورايا كليه تاني يوم قاعده ف البلكونه مع كوباية شاي ويا سلام بقا لو soundtrack بت…
# 493  قد يحزنك العالم و تسعدك كوباية سحلب بالمكسرات .
# 494  - عاملك كوباية شاى بقى من اللى مات ابوها = *بيطبطب على الكوبايه*
# 495  حطيت ايدي في كوباية الشاي بدل الطبق و مافيش بربع جنية تركيز 🤦
# 496  قد يُحزنك العالم و يسعدك كوباية سحلب مثلا
# 497  النهاردة كوباية القهوة وقعت و مكنتش لسه شربت منها بوق حتى وكنت عايزة أبكى على البن المسكوب حرفيا يعنى🤚
# 498  : تفضلوا تتريقوا ع الستات وتقولولهم بتعملوا إيه! تدخلوا المطبح تولعوا في نفسكوا عشان تعملوا كوباية شاي
# 499  : الاكل اللي في الفرن ومغطياه بفويل ومش بيتفتح في بعد حبة ده ببقى هاين عليا ادخل اقعد معاه اشوفه عايز يتقلب، يتزود شوية ميه، كوبا…
# 500  وهتضحي ب خمسة جنيه ي متهور!
# 501  كوباية شاي وسيجارة
# 502  ساعات بتمني بس ابقي كوباية ️️
# 503  حقيقي حقيقي حقيقي محتاجة متبرع يفكرني بمواعيد الدوا و لو مفهاش تعب يجيبلي الشريط و كوباية مية بالمرة .
# 504  : اللى يكسر الكباية ويقرر يلزقها وكله أمل انه كمان هيشرب منها ميحاولش بقى يحط كمان مية سخنة جواها! عشان دى مش بس هتتك…
# 505  كوباية شاى وسندوتشين كده وسمى الله واقعدى ذاكرى
# 506  ثوانى ادخل احلب الجاموسه واحيبلك كوباية لبن
# 507  ثوانى ادخل احلب الجاموسه واجيبلك كوباية لبن
# 508  بس ادوني كوباية شاي طعمه حلو جاي من الكاميرون كتر خيرهم والله ولاد حلال وربنا يجيب لهم ابنهم بالسلامة
# 509  صحيت اتعشيت و شربت سجارة و كوباية الشاي، نرجع نكمل نوم بقي و نقفلهم ساعة
# 510  : وهتضحي ب خمسة جنيه ي متهور!
# 511  صحيت اتعشيت و شربت سجارة و كوباية الشاي، ارجع اكمل نوم بقي و اقفلهم ساعة
# 512  : قد يُحزنك العالم و يسعدك كوباية سحلب او القعده علي الكورنيش دلوقتي.
# 513  : اكيد كنت بتروح كل يوم تشرب كوباية شاى مع الغفير بتاع الڤيلا وتسرسبه فى الكلام يا خلبوص زى افلام الابيض و الاسود كد…
# 514  انا بينى وبين ابويا نفسه فلوس يافاطمه كوباية الشاى بعملها له بخمساية
# 515  : الفرق بينك وبين الغلطة كوباية قهوة اشربها وهتفوق فا مش هتغلط .. اعلان في الجون
# 516  : بحس نهايتي هتكون علي ايد كوباية قهوة حقيرة..
# 517  يسقط العالم وتحيا كوباية الشاي بالنعناع
#
#     class
# 0    EG
# 1    EG
# 2    EG
# 3    EG
# 4    EG
# 5    EG
# 6    EG
# 7    EG
# 8    EG
# 9    EG
# 10   EG
# 11   EG
# 12   EG
# 13   EG
# 14   EG
# 15   EG
# 16   EG
# 17   EG
# 18   EG
# 19   EG
# 20   EG
# 21   EG
# 22   EG
# 23   EG
# 24   EG
# 25   EG
# 26   EG
# 27   EG
# 28   EG
# 29   EG
# ..   ..
# 488  EG
# 489  EG
# 490  EG
# 491  EG
# 492  EG
# 493  EG
# 494  EG
# 495  EG
# 496  EG
# 497  EG
# 498  EG
# 499  EG
# 500  EG
# 501  EG
# 502  EG
# 503  EG
# 504  EG
# 505  EG
# 506  EG
# 507  EG
# 508  EG
# 509  EG
# 510  EG
# 511  EG
# 512  EG
# 513  EG
# 514  EG
# 515  EG
# 516  EG
# 517  EG
#
# [518 rows x 4 columns]

# %%
gulf_mask = latent_semantic_analysis['class'] == 'GULF'

# %%
latent_semantic_analysis[gulf_mask]
# Out:
#       component_1   component_2  \
# 0    8.300281e-04 -9.018917e-05
# 1    1.657562e-03 -1.899227e-04
# 2    6.787565e-03 -9.988934e-05
# 3    2.899447e-03 -3.653068e-04
# 4    5.378612e-03  9.006512e-05
# 5    8.352712e-03 -1.415209e-04
# 6    1.886363e-03 -1.679862e-04
# 7    9.210788e-04  2.758843e-06
# 8    3.828331e-03  3.126708e-04
# 9    3.015537e-04  4.032727e-05
# 10   1.207357e-07  5.752807e-07
# 11   3.828331e-03  3.126708e-04
# 12   1.299360e-04  6.272246e-06
# 13   5.743403e-03 -1.050136e-04
# 14   1.539386e-03 -1.457891e-04
# 15   4.695549e-03 -1.279044e-04
# 16   3.015537e-04  4.032727e-05
# 17   2.063764e-03 -2.337128e-04
# 18   1.091381e-02 -2.282722e-04
# 19   1.652675e-03 -6.925193e-05
# 20   6.431422e-04  1.243963e-04
# 21   3.155613e-04  3.358394e-05
# 22   6.431422e-04  1.243963e-04
# 23   2.864793e-03  2.451387e-04
# 24   2.864793e-03  2.451387e-04
# 25   1.104499e-03  1.110469e-04
# 26   1.104499e-03  1.110469e-04
# 27   1.617705e-03 -7.174002e-05
# 28   1.623685e-03  1.291789e-04
# 29   1.623685e-03  1.291789e-04
# ..            ...           ...
# 392  2.533678e-03  1.202888e-03
# 393  1.132493e-02 -5.380610e-05
# 394  2.081694e-03  3.036396e-03
# 395  1.208685e-03  1.043152e-03
# 396  1.208685e-03  1.043152e-03
# 397  7.034013e-03  2.157033e-03
# 398  1.044215e-03  1.078267e-03
# 399  2.533678e-03  1.202888e-03
# 400  8.311376e-04  1.097452e-03
# 401  1.535793e-03  1.694352e-03
# 402  2.726662e-03  1.362204e-04
# 403  1.100581e-02  6.296765e-04
# 404  1.424446e-03 -2.945120e-03
# 405  4.439948e-03 -2.406390e-04
# 406  3.568539e-05  9.325981e-01
# 407  3.240545e-05  9.877912e-01
# 408  3.568539e-05  9.325981e-01
# 409  3.240545e-05  9.877912e-01
# 410  3.552100e-05  9.585034e-01
# 411  1.367985e-03  8.275739e-04
# 412  3.499357e-03  1.217105e-03
# 413  3.137970e-02  2.506242e-04
# 414  3.240545e-05  9.877912e-01
# 415  1.015536e-02  1.143312e-03
# 416 -0.000000e+00  0.000000e+00
# 417  1.417810e-03  1.710937e-03
# 418  1.799442e-03  2.062787e-03
# 419  8.311376e-04  1.097452e-03
# 420  5.096435e-03  1.676451e-03
# 421  4.073210e-03  3.791311e-05
#
#                                                                                                                   cleaned_text  \
# 0    : على الاقل ارحم من ان تتعود على وجود احد ويغرقك اهتمام وحب ويغنيك عن الدنيا وبنص الطريج يخليك تعاني وتت…
# 1    وحدة مكافحة الموز في الطريج
# 2    انا صوت الفريج وبنتٍ تناديك تدليك الفرح وينه انا ثوبك وسبحةٍ في يدك واللي راح من عمرك انا اشيله أدليك الطريج اللي…
# 3    اوك مسافة الطريج يايتلچ ‍️‍️‍️
# 4    كلام جميل لكن وين التطبيق.طلع قانون للخدم ونشر بالجريدة الرسمية من زمان وللحين احنا ناطرين ا…
# 5    الثالث علي الطريج طولي بالج اول الله️
# 6    لما أكون مستعيله ويغلط السواق ف الطريج
# 7    احبك كثر ماتوقف على جنب الطريج اشجار احبك كثر مايقسى الشتا وتهاجر طيوره..
# 8    لحد يسلمي الAUX ويقولي بسج توقفين بنص الاغنيه, الطريج دقايق وانا عندي اغنيه بسمعها!
# 9    انا نظامي اخليهم يسمعون اول دقايق والي بعده
# 10   حدة حدة
# 11   : لحد يسلمي الAUX ويقولي بسج توقفين بنص الاغنيه, الطريج دقايق وانا عندي اغنيه بسمعها!
# 12   ماشفت هالشي شنو هذا
# 13   متعني للعاشره عشان اتقهوى يالله الخيره ماتحسفت الا يوم وصلت نص الطريج
# 14   بنجر علي التاير بنص الطريج و رجعت بتكسي LIVE on
# 15   ايي والله بغيت اغير طريجي والسبه اني مابي افتحله الطريج وداااايس
# 16   : انا نظامي اخليهم يسمعون اول دقايق والي بعده
# 17   الطريج يخوف بليل
# 18   الله يحييچ يلا مسافة الطريج وأكون عندچ
# 19   متعه في خط سريع فاضي بالليل ويمك غالي تحبه وبعد سوالفه تسمع طرب ابو نوره ودك الطريج يطول️ !
# 20   شنو هذا ابي اعرف !!
# 21   شلون جذي
# 22   : شنو هذا ابي اعرف !!
# 23   انزين الناس منحاشة لي وين هي جايتكم جايتكم
# 24   : انزين الناس منحاشة لي وين هي جايتكم جايتكم
# 25   ريتويت اذا كان عبالك يوم القيامة
# 26   : ريتويت اذا كان عبالك يوم القيامة
# 27   : • خاطري طاب من ذاك الفريج صـد قلـبي وانـا تـابع هـواه • كل يوم وانا أدق الطريج ماأحد قـال لي وا…
# 28   تقريباً كان قبل سنوات .. يوم مانساه!
# 29   : تقريباً كان قبل سنوات .. يوم مانساه!
# ..                                      ...
# 392  ؛ رسالة وصلتنا : غطاء هاتف. مكسور فـ منتصف الشارع بجوار مغسلة جود للملابس. مقابل إدارة المياه :…
# 393  احمد ربك حصلت اربعه
# 394  مغسلة الجوري
# 395  مغسلة ديكور انطلاق اكبر مهرجان للخصومات من زينكو خصم يبدأ من % حتى % …
# 396  : مغسلة ديكور انطلاق اكبر مهرجان للخصومات من زينكو خصم يبدأ من % حتى % …
# 397  من الخاص السلام عليكم ايش افضل مغسلة البطانيات في وشكرا
# 398  مغسلة ديكور مزدوجه انيقه جدامن dreamsste **اكبر حملة تخفيضات على جميع…
# 399  : ؛ رسالة وصلتنا : غطاء هاتف. مكسور فـ منتصف الشارع بجوار مغسلة جود للملابس. مقابل إدارة المياه :…
# 400  عرض خاص لأعضاء جمعية المهندسين الكويتية من مغسلة ذا ديزرت المركزية الأسعار المعلنة خاصة لأعضاء…
# 401  من رسائلكم مطلوب محل للايجار يصلح ل مغسلة سيارات ضمن الميزتلي
# 402  : لو اني فتحت مغسلة في الصناعية كان اشرفلي من دخلتي على هل جامعة
# 403  متاح عدة مغسلة كاملة للبيع لو حد عايز يكلمني العدة عبارة عن : كاتشر إيطالي حصان بار بالخرطوم و المسدس...
# 404  : اعتقد ان أول جامعة سعودية غسلت شهادة دكتوراه من نوع هي جامعة الملك سعود وان أكبر مغسلة للشهادات الآن هي جام…
# 405  : لاأزال لا أستوعب سبب عدم منح تراخيص لجمعيات تعاونية تنتشر في الاحياء و يصمًم لها نموذج موحًد كما…
# 406  ضمان سنتين شطاف كاديا شطاف داليا ضمان سنوات شاور مع مسطرة(صاعد…
# 407  ضمان سنتين شطاف كاديا شطاف داليا ضمان سنوات شاور مع مسطرة(صاعد نازل) كروم شاور مع مسطرة(صاعد…
# 408  ضمان سنتين شطاف كاديا شطاف داليا ضمان سنوات شاور مع مسطرة(صاعد نا…
# 409  ضمان سنتين شطاف كاديا شطاف داليا ضمان سنوات شاور مع مسطرة(صاعد نازل) كروم شاور مع مسطرة(صاعد نا…
# 410  ضمان سنتين شطاف كاديا شطاف داليا ضمان سنوات شاور مع مسطرة(صاعد نازل)…
# 411  : لكم أن تتخيلوا قساوة المشهد وألم الشعور عندما قبلت أمي على جبينها قبلة الوداع وهي في مغسلة الاموات ، اللهم ارحم أمي.
# 412  : فكرة انارة مغسلة مع انارة مركزة على الورد
# 413  مرحبا مكتب استقدام الهند يوجد لدي: عامل مزارع عامل عادي عامل استراحة عامل مغسلة عامل نظافة عامل مطعم عامل شاورما الواتساب
# 414  : ضمان سنتين شطاف كاديا شطاف داليا ضمان سنوات شاور مع مسطرة(صاعد نازل) كروم شاور مع مسطرة(صاعد…
# 415  : اسرع طريقة صاروخيه لكسب الاموال من عامل فى مغسلة سيارات الى مطوع يرش مويه مقري
# 416  …
# 417  بغزل حمامي كلهم سيفون الا انت مغسلة
# 418  حاشا هذي ماهي امراه هاذي مغسلة سيارات
# 419  : عرض خاص لأعضاء جمعية المهندسين الكويتية من مغسلة ذا ديزرت المركزية الأسعار المعلنة خاصة لأعضاء…
# 420  والله ما أحد مستانس غير طلاب الابتدائي متسدحين بايباداتهم وشهاداتهم كلها واحد واحد واحد تقول فاتورة مغسلة
# 421  ماشاء الله ... ياليث يعمم في الطرق السريعة مثل هذه الخدمات ويحافظ عليها ويتم مراقبتها ... أنا لست مهندسة لكن احدى…
#
#     class
# 0    GULF
# 1    GULF
# 2    GULF
# 3    GULF
# 4    GULF
# 5    GULF
# 6    GULF
# 7    GULF
# 8    GULF
# 9    GULF
# 10   GULF
# 11   GULF
# 12   GULF
# 13   GULF
# 14   GULF
# 15   GULF
# 16   GULF
# 17   GULF
# 18   GULF
# 19   GULF
# 20   GULF
# 21   GULF
# 22   GULF
# 23   GULF
# 24   GULF
# 25   GULF
# 26   GULF
# 27   GULF
# 28   GULF
# 29   GULF
# ..    ...
# 392  GULF
# 393  GULF
# 394  GULF
# 395  GULF
# 396  GULF
# 397  GULF
# 398  GULF
# 399  GULF
# 400  GULF
# 401  GULF
# 402  GULF
# 403  GULF
# 404  GULF
# 405  GULF
# 406  GULF
# 407  GULF
# 408  GULF
# 409  GULF
# 410  GULF
# 411  GULF
# 412  GULF
# 413  GULF
# 414  GULF
# 415  GULF
# 416  GULF
# 417  GULF
# 418  GULF
# 419  GULF
# 420  GULF
# 421  GULF
#
# [422 rows x 4 columns]

# %%
latent_semantic_analysis[(latent_semantic_analysis['class'] == 'EG') 
                         & (latent_semantic_analysis.component_2 > .050)]

# %%
latent_semantic_analysis[(latent_semantic_analysis['class'] == 'GULF') 
                         & (latent_semantic_analysis.component_2 > .50)]
